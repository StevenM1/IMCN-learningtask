# %%
from __future__ import division
import pandas as pd
import os
import numpy as np
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Creates design files for the instrumental learning task
#
# An experimental session containts two task, each of which is performed in three runs: 1. a vanilla instrumental learning task, and 2. a SAT-version of the task. Task order is counterbalanced, stimuli are updated between tasks. Stimuli are assigned a value randomly (i.e. also counterbalanced).
#
#
# ##### Design files are DataFrames with the following info per trial:
# 1. `stim_set`: Which stimulus set is presented? [0, 1, 2, 3, 4, 5, 6]
# 2. `correct_stim_lr`: What is the location (on the screen) of the winning stim? [0 = left, 1=right]
# 3. `p_win_left`: Probability of winning if left is chosen
# 4. `p_win_right'`: Probability of winning if right is chosen
# 5. `p_win_correct`: Probability of winning if correct answer is chosen
# 6. `p_win_incorrect`: Probability of winning if incorrect answer is chosen
# 7. `phase_x`: Duration for phase `x` (in s; see below)
# 8. `stim_left`, `stim_right`:  Stimuli that are presented left, right
# 9. `stim_high`, `stim_low`: Stimuli that correspond to the high, low probability of winning
#
# ##### Trial phases:
# 1. Fixation cross (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 2. Cue (0.75s)
# 3. Fixation cross (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 4. Stimulus (2s)
# 5. Stimulus choice (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 6. Feedback (0.5s)
# 7. ITI (jittered timing) `[0.25, 0.5, ..., 3.25s]`
#
# The timings mentioned above are for the MR version of the SAT task. Without MR, the jittered fixation crosses are skipped, the stimulus duration is not fixed to 2 seconds but ends when the participant gave a response, and highlight of choice is a fixed duration. ITI is shortened but still jittered a bit.
#
# ##### Potential future options:
# 1. Pseudorandomize trial order;
# 2. Optimize design (have code for this)

# %%
def get_settings(tr=2, verbose=True):
    p_win = [[.8, .2], [.7, .3], [.65, .35]]
    n_runs = 3
    n_sessions = 2
    if tr == 2:
        n_trials = 144
        jitters = [0.5, 0.75, 1, 1.25, 1.5]
        volumes_per_trial = 4
    
    n_trials_per_stimset = n_trials/len(p_win)
    trial_duration = volumes_per_trial*tr
    total_duration = trial_duration*n_trials
    total_duration_min = total_duration/60
    total_volumes = 1 + n_trials*volumes_per_trial
    
    if verbose:
        print('Settings:\n\n\
        Sessions: {n_sessions}\n\
        Trials per run: {n_trials}\n\
        Assuming a TR of {tr} seconds\n\
        Jitter options: {jitters} seconds\n\
        Total duration: {tr}*{trial_duration}*{n_trials} = {total_duration} seconds = {total_duration_min} min\n\
        Total number of volumes necessary: 1+{n_trials}*{volumes_per_trial} = {total_volumes} + warm-up pulses'.format(**locals()))
        
    return({'jitter': jitters,
            'n_trials': n_trials,
            'ps': p_win})

# %%
def generate_block_design(n_trials, jitters, 
                          ps,
                          stim_sets=[0,1,2],
                          mr_design=True, 
                          include_cue=True, 
                          phase_durations=['jittered', 0.75, 'jittered', 2, 'jittered', 0.75, 'iti'],
                          trial_duration=8,
                          practice=False):
    """ Generates design for a single block.
    
    jitters: list of possible jitter durations, in seconds (e.g., [0.5, 1, 1.5])
    mr_design: bool. If False, all phases that are jittered are set to -1 and skipped in the experiment; iti is set lower
    include_cue: bool. If False, the cue phase duration will be set to -1.
    """
    correct_stim_lr = [0, 1]
    if include_cue:
        cues = ['SPD', 'ACC']
    else:
        cues = ['']
    combs = list(itertools.product(stim_sets, correct_stim_lr, cues))
    
    # make basic df
    design = pd.DataFrame(combs * int(np.ceil((n_trials/len(combs)))), 
                          columns=['stimulus_set', 'correct_stim_lr', 'cue'])
    # randomize
    design = design.sample(frac=1).reset_index(drop=True)#.reset_index('trial_ID')
    n_trials_real = design.shape[0]
    design = design.iloc[:n_trials]
    
    if not n_trials == n_trials_real:
        print('WARNING: not totally balanced (%d not a multitude of %d)' %(n_trials, len(combs)))
    
    # Add probabilities (left/right and correct/incorrect - this is redundant, I know)
    design['p_win_left'] = None
    design['p_win_right'] = None
    design['p_win_correct'] = None
    design['p_win_incorrect'] = None
    for stim_set, p_win in zip(stim_sets, ps):
        p_win_high, p_win_low = p_win[0], p_win[1]
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 0), 'p_win_left'] = p_win_high
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 1), 'p_win_right'] = p_win_high
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 1), 'p_win_left'] = p_win_low
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 0), 'p_win_right'] = p_win_low
        design.loc[(design.stimulus_set==stim_set), 'p_win_correct'] = p_win_high
        design.loc[(design.stimulus_set==stim_set), 'p_win_incorrect'] = p_win_low
    
    # Add phase durations
    for phase, duration in enumerate(phase_durations):
        col_key = 'phase_' + str(phase+1)
        if duration == 'jittered':
            design[col_key] = np.random.choice(jitters, size=n_trials, replace=True)
        elif duration == 'iti':
            iti_phase_col_key = 'phase_' + str(phase+1)
        else:
            design[col_key] = duration
    
    design[iti_phase_col_key] = trial_duration - design[[col for col in design.columns if 'phase' in col]].apply(sum, axis=1)

    
    if not mr_design:
        # remove jitters
        for phase, duration in enumerate(phase_durations):
            col_key = 'phase_' + str(phase+1)
            if duration == 'jittered':
                design[col_key] = -.0001
            # set iti to randomly sampled from [0.5, 1]
            if duration == 'iti':
                design[col_key] = np.random.uniform(0.5, 1, design.shape[0])
        # set choice highlight phase to fixed 0.5
        design['phase_5'] = 0.5

    if not include_cue:
        # always skip cue
        design['phase_2'] = -.0001
        
    if practice and include_cue:
        design.cue.iloc[0] = 'ACC'

    return(design)

#generate_block_design(18, [0, 1, 2])

# %%
def get_task_type(run, subject_id, is_practice=False, is_debug=False):    
    def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            return False
    
    if is_debug:
        if run > 3:
            include_cue = False
        else:
            include_cue = True
    elif is_practice:
        # start practice without cues
        if run <= 2:
            include_cue = False
        else:
            include_cue = True

    elif is_number(subject_id):
        if (int(subject_id) % 2) == 0:
            if run > 3:
                include_cue = False
            else:
                include_cue = True
        else:
            if run > 3:
                include_cue = True
            else:
                include_cue = False
                
    # Return stimuli
    if run <= 3:
        stim_sets = [0,1,2]
    elif run > 3:
        stim_sets = [3,4,5]
            
    return include_cue, stim_sets

# %%
def counterbalance_stimuli(subject_id, all_sets=[['A', 'B'],
                                                 ['J', 'K'], 
                                                 ['M', 'N'],
                                                 ['O', 'P'],
                                                 ['W', 'X'],
                                                 ['c', 'e']]):
        import itertools
        from copy import deepcopy

        n_shifts = [0, 1, 2]  # assuming 6 stimuli, but you could do more, or less...
        rev_inner = [False, True]
        switch_sets = [False, True]

        cb_df = pd.DataFrame(list(itertools.product(switch_sets, n_shifts, rev_inner)),
                             columns=['switch_sets', 'n_shifts', 'rev_inner'])
        cb_df['pp'] = np.arange(1, cb_df.shape[0] + 1)
        for set_n in range(1, 13):
            cb_df['stim_%d' % set_n] = None

        for pp in cb_df['pp']:
            idx = cb_df.pp == pp
            switch_sets = cb_df.loc[idx, 'switch_sets'].iloc[0]
            reverse_inner = cb_df.loc[idx, 'rev_inner'].iloc[0]
            n_shifts = cb_df.loc[idx, 'n_shifts'].iloc[0]

            if switch_sets:
                sets = deepcopy([all_sets[3:], all_sets[:3]])
            else:
                sets = deepcopy([all_sets[:3], all_sets[3:]])

            sets_allocated = 0
            for set_n, set_ in enumerate(sets):
                for i in range(n_shifts):
                    set_.insert(len(set_), set_.pop(0))  # move first item to last place

                if reverse_inner:
                    set_ = [x[::-1] for x in set_]  # reverse inner order

                # print('pp %d, %d, %s' % (pp, set_n, set_))
                #### NB: you could just use set_ as a final result; the placing in the dataframe and then reverting
                # back to a nested list is definitely not necessary but may help clarify what's going on here...
                for to_allocate in [0, 1, 2]:
                    for to_allocate_i in [0, 1]:
                        cb_df.loc[idx, 'stim_%d' % (sets_allocated + 1)] = set_[to_allocate][to_allocate_i]
                        sets_allocated += 1

        pp_zero_based = int(subject_id) - 1
        row_iloc = int(pp_zero_based - np.floor(pp_zero_based / 12) * 12)
        colnames = cb_df.columns
        stim_list = cb_df.iloc[row_iloc][[x for x in colnames if 'stim' in x]].values.tolist()
        stim_nested_list = [[stim_list[0 + y * 2], stim_list[1 + y * 2]] for y in range(6)]
        print('Stimuli/set order for this pp: %s' % stim_nested_list)
        return stim_nested_list

# %%
def get_stimuli(subject_id, design):    
    if subject_id == 'PRACTICE':
        # The practice session always gets different stimuli
        stim_sets = [['j', 'm'], ['s', 'y'], ['u', 'n'], ['j', 'm'], ['s', 'y'], ['u', 'n']]
    else:
        stim_sets = [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'],  ['W', 'X'], ['c', 'e']]
    if subject_id == 'DEBUG' or subject_id == 'PRACTICE':
        # just use counterbalancing order 1 for practice & debug
        subject_id = 1

    all_stim = counterbalance_stimuli(subject_id, all_sets=stim_sets)
    design['stim_left'] = None
    design['stim_right'] = None
    design['stim_high'] = None
    design['stim_low'] = None

    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        design.loc[idx_this_stim, 'stim_high'] = all_stim[i][0]
        design.loc[idx_this_stim, 'stim_low'] = all_stim[i][1]

    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        idx_this_stim_nonrev = (idx_this_stim) & (design.correct_stim_lr == 0)
        idx_this_stim_rev = (idx_this_stim) & (design.correct_stim_lr == 1)

        design.loc[idx_this_stim_nonrev, 'stim_left'] = design.loc[idx_this_stim_nonrev, 'stim_high']
        design.loc[idx_this_stim_nonrev, 'stim_right'] = design.loc[idx_this_stim_nonrev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_left'] = design.loc[idx_this_stim_rev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_right'] = design.loc[idx_this_stim_rev, 'stim_high']
   
    return design

# %%
tr = 2
n_subjects = 21
n_runs = 3

save_dir = '../designs'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.hstack([np.arange(1,n_subjects+1), 'DEBUG']):
    designs_this_session = []
    print(subject_id)
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in range(1,n_runs*2+1):
        settings = get_settings(tr=tr)
        include_cue, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(settings['n_trials'], settings['jitter'], ps=settings['ps'],
                                       stim_sets=stim_set,
                                       mr_design=False, include_cue=include_cue)
        design['block'] = run
        designs_this_session.append(design)
    
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    fn = 'sub-' + str(subject_id).zfill(2) + '_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# 1
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 1, run: 6, cue: True
# Stimuli/set order for this pp: [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'], ['W', 'X'], ['c', 'e']]
# sub-01_design
# 2
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 2, run: 6, cue: False
# Stimuli/set order for this pp: [['B', 'A'], ['K', 'J'], ['N', 'M'], ['P', 'O'], ['X', 'W'], ['e', 'c']]
# sub-02_design
# 3
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 3, run: 6, cue: True
# Stimuli/set order for this pp: [['J', 'K'], ['M', 'N'], ['A', 'B'], ['W', 'X'], ['c', 'e'], ['O', 'P']]
# sub-03_design
# 4
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 4, run: 6, cue: False
# Stimuli/set order for this pp: [['K', 'J'], ['N', 'M'], ['B', 'A'], ['X', 'W'], ['e', 'c'], ['P', 'O']]
# sub-04_design
# 5
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 5, run: 6, cue: True
# Stimuli/set order for this pp: [['M', 'N'], ['A', 'B'], ['J', 'K'], ['c', 'e'], ['O', 'P'], ['W', 'X']]
# sub-05_design
# 6
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 6, run: 6, cue: False
# Stimuli/set order for this pp: [['N', 'M'], ['B', 'A'], ['K', 'J'], ['e', 'c'], ['P', 'O'], ['X', 'W']]
# sub-06_design
# 7
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 7, run: 6, cue: True
# Stimuli/set order for this pp: [['O', 'P'], ['W', 'X'], ['c', 'e'], ['A', 'B'], ['J', 'K'], ['M', 'N']]
# sub-07_design
# 8
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 8, run: 6, cue: False
# Stimuli/set order for this pp: [['P', 'O'], ['X', 'W'], ['e', 'c'], ['B', 'A'], ['K', 'J'], ['N', 'M']]
# sub-08_design
# 9
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 9, run: 6, cue: True
# Stimuli/set order for this pp: [['W', 'X'], ['c', 'e'], ['O', 'P'], ['J', 'K'], ['M', 'N'], ['A', 'B']]
# sub-09_design
# 10
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 10, run: 6, cue: False
# Stimuli/set order for this pp: [['X', 'W'], ['e', 'c'], ['P', 'O'], ['K', 'J'], ['N', 'M'], ['B', 'A']]
# sub-10_design
# 11
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 11, run: 6, cue: True
# Stimuli/set order for this pp: [['c', 'e'], ['O', 'P'], ['W', 'X'], ['M', 'N'], ['A', 'B'], ['J', 'K']]
# sub-11_design
# 12
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 12, run: 6, cue: False
# Stimuli/set order for this pp: [['e', 'c'], ['P', 'O'], ['X', 'W'], ['N', 'M'], ['B', 'A'], ['K', 'J']]
# sub-12_design
# 13
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 13, run: 6, cue: True
# Stimuli/set order for this pp: [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'], ['W', 'X'], ['c', 'e']]
# sub-13_design
# 14
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 14, run: 6, cue: False
# Stimuli/set order for this pp: [['B', 'A'], ['K', 'J'], ['N', 'M'], ['P', 'O'], ['X', 'W'], ['e', 'c']]
# sub-14_design
# 15
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 15, run: 6, cue: True
# Stimuli/set order for this pp: [['J', 'K'], ['M', 'N'], ['A', 'B'], ['W', 'X'], ['c', 'e'], ['O', 'P']]
# sub-15_design
# 16
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 16, run: 6, cue: False
# Stimuli/set order for this pp: [['K', 'J'], ['N', 'M'], ['B', 'A'], ['X', 'W'], ['e', 'c'], ['P', 'O']]
# sub-16_design
# 17
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 17, run: 6, cue: True
# Stimuli/set order for this pp: [['M', 'N'], ['A', 'B'], ['J', 'K'], ['c', 'e'], ['O', 'P'], ['W', 'X']]
# sub-17_design
# 18
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 18, run: 6, cue: False
# Stimuli/set order for this pp: [['N', 'M'], ['B', 'A'], ['K', 'J'], ['e', 'c'], ['P', 'O'], ['X', 'W']]
# sub-18_design
# 19
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 19, run: 6, cue: True
# Stimuli/set order for this pp: [['O', 'P'], ['W', 'X'], ['c', 'e'], ['A', 'B'], ['J', 'K'], ['M', 'N']]
# sub-19_design
# 20
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 20, run: 6, cue: False
# Stimuli/set order for this pp: [['P', 'O'], ['X', 'W'], ['e', 'c'], ['B', 'A'], ['K', 'J'], ['N', 'M']]
# sub-20_design
# 21
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 3, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 5, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: 21, run: 6, cue: True
# Stimuli/set order for this pp: [['W', 'X'], ['c', 'e'], ['O', 'P'], ['J', 'K'], ['M', 'N'], ['A', 'B']]
# sub-21_design
# DEBUG
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 1, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 2, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 3, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 6, cue: False
# Stimuli/set order for this pp: [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'], ['W', 'X'], ['c', 'e']]
# sub-DEBUG_design

# %%
design
# Out:
#      stimulus_set  correct_stim_lr  cue p_win_left p_win_right p_win_correct  \
# 0               1                0  ACC        0.7         0.3           0.7
# 1               1                1  SPD        0.3         0.7           0.7
# 2               2                0  SPD       0.65        0.35          0.65
# 3               2                1  ACC       0.35        0.65          0.65
# 4               1                1  SPD        0.3         0.7           0.7
# 5               1                1  SPD        0.3         0.7           0.7
# 6               1                1  ACC        0.3         0.7           0.7
# 7               0                1  ACC        0.2         0.8           0.8
# 8               1                1  SPD        0.3         0.7           0.7
# 9               1                0  ACC        0.7         0.3           0.7
# 10              2                0  SPD       0.65        0.35          0.65
# 11              0                1  SPD        0.2         0.8           0.8
# 12              0                0  SPD        0.8         0.2           0.8
# 13              0                1  SPD        0.2         0.8           0.8
# 14              2                0  SPD       0.65        0.35          0.65
# 15              0                0  ACC        0.8         0.2           0.8
# 16              2                0  ACC       0.65        0.35          0.65
# 17              2                1  SPD       0.35        0.65          0.65
# 18              1                0  ACC        0.7         0.3           0.7
# 19              1                0  SPD        0.7         0.3           0.7
# 20              1                0  ACC        0.7         0.3           0.7
# 21              2                1  SPD       0.35        0.65          0.65
# 22              0                1  ACC        0.2         0.8           0.8
# 23              0                1  SPD        0.2         0.8           0.8
# 24              2                1  SPD       0.35        0.65          0.65
# 25              1                1  ACC        0.3         0.7           0.7
# 26              2                0  SPD       0.65        0.35          0.65
# 27              2                1  ACC       0.35        0.65          0.65
# 28              0                0  ACC        0.8         0.2           0.8
# 29              0                0  ACC        0.8         0.2           0.8
# ..            ...              ...  ...        ...         ...           ...
# 114             4                1             0.3         0.7           0.7
# 115             3                1             0.2         0.8           0.8
# 116             4                0             0.7         0.3           0.7
# 117             5                1            0.35        0.65          0.65
# 118             5                0            0.65        0.35          0.65
# 119             4                0             0.7         0.3           0.7
# 120             4                0             0.7         0.3           0.7
# 121             4                0             0.7         0.3           0.7
# 122             4                0             0.7         0.3           0.7
# 123             3                1             0.2         0.8           0.8
# 124             5                0            0.65        0.35          0.65
# 125             3                1             0.2         0.8           0.8
# 126             4                1             0.3         0.7           0.7
# 127             3                0             0.8         0.2           0.8
# 128             3                1             0.2         0.8           0.8
# 129             3                1             0.2         0.8           0.8
# 130             5                1            0.35        0.65          0.65
# 131             5                1            0.35        0.65          0.65
# 132             3                0             0.8         0.2           0.8
# 133             5                1            0.35        0.65          0.65
# 134             4                0             0.7         0.3           0.7
# 135             4                1             0.3         0.7           0.7
# 136             3                1             0.2         0.8           0.8
# 137             3                1             0.2         0.8           0.8
# 138             5                0            0.65        0.35          0.65
# 139             3                1             0.2         0.8           0.8
# 140             3                0             0.8         0.2           0.8
# 141             5                1            0.35        0.65          0.65
# 142             3                1             0.2         0.8           0.8
# 143             4                1             0.3         0.7           0.7
#
#     p_win_incorrect  phase_1  phase_2  phase_3  phase_4  phase_5  phase_6  \
# 0               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2              0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3              0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 6               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 7               0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 8               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 9               0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 10             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 11              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 12              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 13              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 14             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 15              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 16             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 17             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 18              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 19              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 20              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 21             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 22              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 23              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 24             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 25              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 26             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 27             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 28              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 29              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# ..              ...      ...      ...      ...      ...      ...      ...
# 114             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 115             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 116             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 117            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 118            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 119             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 120             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 121             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 122             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 123             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 124            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 125             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 126             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 127             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 128             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 129             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 130            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 131            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 132             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 133            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 134             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 135             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 136             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 137             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 138            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 139             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 140             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 141            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 142             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 143             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
#
#       phase_7  block stim_left stim_right stim_high stim_low
# 0    0.511174      1         J          K         J        K
# 1    0.730962      1         K          J         J        K
# 2    0.512689      1         M          N         M        N
# 3    0.562294      1         N          M         M        N
# 4    0.692286      1         K          J         J        K
# 5    0.753136      1         K          J         J        K
# 6    0.779852      1         K          J         J        K
# 7    0.619151      1         B          A         A        B
# 8    0.756318      1         K          J         J        K
# 9    0.557812      1         J          K         J        K
# 10   0.530813      1         M          N         M        N
# 11   0.506568      1         B          A         A        B
# 12   0.830547      1         A          B         A        B
# 13   0.609275      1         B          A         A        B
# 14   0.638139      1         M          N         M        N
# 15   0.983784      1         A          B         A        B
# 16   0.980208      1         M          N         M        N
# 17   0.740382      1         N          M         M        N
# 18   0.541789      1         J          K         J        K
# 19   0.782554      1         J          K         J        K
# 20   0.719308      1         J          K         J        K
# 21   0.561271      1         N          M         M        N
# 22   0.829784      1         B          A         A        B
# 23   0.576418      1         B          A         A        B
# 24   0.619032      1         N          M         M        N
# 25   0.729752      1         K          J         J        K
# 26   0.706591      1         M          N         M        N
# 27   0.692954      1         N          M         M        N
# 28   0.989310      1         A          B         A        B
# 29   0.504504      1         A          B         A        B
# ..        ...    ...       ...        ...       ...      ...
# 114  0.885417      6         X          W         W        X
# 115  0.702958      6         P          O         O        P
# 116  0.797519      6         W          X         W        X
# 117  0.926840      6         e          c         c        e
# 118  0.768951      6         c          e         c        e
# 119  0.740577      6         W          X         W        X
# 120  0.821763      6         W          X         W        X
# 121  0.527855      6         W          X         W        X
# 122  0.535577      6         W          X         W        X
# 123  0.916411      6         P          O         O        P
# 124  0.856795      6         c          e         c        e
# 125  0.818167      6         P          O         O        P
# 126  0.760471      6         X          W         W        X
# 127  0.634059      6         O          P         O        P
# 128  0.994803      6         P          O         O        P
# 129  0.617314      6         P          O         O        P
# 130  0.701218      6         e          c         c        e
# 131  0.714094      6         e          c         c        e
# 132  0.981157      6         O          P         O        P
# 133  0.871453      6         e          c         c        e
# 134  0.797343      6         W          X         W        X
# 135  0.666445      6         X          W         W        X
# 136  0.797633      6         P          O         O        P
# 137  0.895900      6         P          O         O        P
# 138  0.906151      6         c          e         c        e
# 139  0.790672      6         P          O         O        P
# 140  0.818304      6         O          P         O        P
# 141  0.662459      6         e          c         c        e
# 142  0.811501      6         P          O         O        P
# 143  0.641770      6         X          W         W        X
#
# [864 rows x 19 columns]

# %% [markdown]
# ## For debug, we create a nice a short session

# %%
tr = 2
n_subjects = 1
n_runs = 3

save_dir = '../designs'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.hstack(['DEBUG']):
    designs_this_session = []
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in range(1,n_runs*2+1):
        settings = get_settings(tr=tr)
        include_cue, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(6, settings['jitter'], ps=settings['ps'],
                                       stim_sets=stim_set,
                                       mr_design=False, include_cue=include_cue)
        design['block'] = run
        designs_this_session.append(design)
    
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    fn = 'sub-' + str(subject_id).zfill(2) + '_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 1, cue: True
# WARNING: not totally balanced (6 not a multitude of 12)
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 2, cue: True
# WARNING: not totally balanced (6 not a multitude of 12)
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 3, cue: True
# WARNING: not totally balanced (6 not a multitude of 12)
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 4, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 5, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: DEBUG, run: 6, cue: False
# Stimuli/set order for this pp: [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'], ['W', 'X'], ['c', 'e']]
# sub-DEBUG_design

# %%
design
# Out:
#    stimulus_set  correct_stim_lr  cue p_win_left p_win_right p_win_correct  \
# 0             1                0  ACC        0.7         0.3           0.7
# 1             0                1  ACC        0.2         0.8           0.8
# 2             2                0  ACC       0.65        0.35          0.65
# 3             2                0  SPD       0.65        0.35          0.65
# 4             2                1  SPD       0.35        0.65          0.65
# 5             1                1  ACC        0.3         0.7           0.7
# 0             2                1  SPD       0.35        0.65          0.65
# 1             2                0  SPD       0.65        0.35          0.65
# 2             0                0  ACC        0.8         0.2           0.8
# 3             0                0  SPD        0.8         0.2           0.8
# 4             0                1  ACC        0.2         0.8           0.8
# 5             1                0  ACC        0.7         0.3           0.7
# 0             2                1  ACC       0.35        0.65          0.65
# 1             0                0  SPD        0.8         0.2           0.8
# 2             1                0  ACC        0.7         0.3           0.7
# 3             2                0  SPD       0.65        0.35          0.65
# 4             2                1  SPD       0.35        0.65          0.65
# 5             1                0  SPD        0.7         0.3           0.7
# 0             4                0             0.7         0.3           0.7
# 1             5                1            0.35        0.65          0.65
# 2             3                0             0.8         0.2           0.8
# 3             4                1             0.3         0.7           0.7
# 4             5                0            0.65        0.35          0.65
# 5             3                1             0.2         0.8           0.8
# 0             5                0            0.65        0.35          0.65
# 1             5                1            0.35        0.65          0.65
# 2             3                1             0.2         0.8           0.8
# 3             4                1             0.3         0.7           0.7
# 4             3                0             0.8         0.2           0.8
# 5             4                0             0.7         0.3           0.7
# 0             5                0            0.65        0.35          0.65
# 1             3                0             0.8         0.2           0.8
# 2             4                1             0.3         0.7           0.7
# 3             5                1            0.35        0.65          0.65
# 4             4                0             0.7         0.3           0.7
# 5             3                1             0.2         0.8           0.8
#
#   p_win_incorrect  phase_1  phase_2  phase_3  phase_4  phase_5  phase_6  \
# 0             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 0            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 0            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4            0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 0             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 1            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 2             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 3             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 4            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 5             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 0            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 1            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 2             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 3             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 4             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 5             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 0            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 1             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 2             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 3            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 4             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 5             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
#
#     phase_7  block stim_left stim_right stim_high stim_low
# 0  0.619372      1         J          K         J        K
# 1  0.599637      1         B          A         A        B
# 2  0.975976      1         M          N         M        N
# 3  0.854439      1         M          N         M        N
# 4  0.691520      1         N          M         M        N
# 5  0.607634      1         K          J         J        K
# 0  0.804113      2         N          M         M        N
# 1  0.670749      2         M          N         M        N
# 2  0.698915      2         A          B         A        B
# 3  0.772738      2         A          B         A        B
# 4  0.973870      2         B          A         A        B
# 5  0.557718      2         J          K         J        K
# 0  0.755928      3         N          M         M        N
# 1  0.773017      3         A          B         A        B
# 2  0.514228      3         J          K         J        K
# 3  0.646445      3         M          N         M        N
# 4  0.920744      3         N          M         M        N
# 5  0.653322      3         J          K         J        K
# 0  0.627899      4         W          X         W        X
# 1  0.518382      4         e          c         c        e
# 2  0.564778      4         O          P         O        P
# 3  0.632483      4         X          W         W        X
# 4  0.765732      4         c          e         c        e
# 5  0.780205      4         P          O         O        P
# 0  0.833005      5         c          e         c        e
# 1  0.575403      5         e          c         c        e
# 2  0.500812      5         P          O         O        P
# 3  0.766344      5         X          W         W        X
# 4  0.906364      5         O          P         O        P
# 5  0.670639      5         W          X         W        X
# 0  0.963591      6         c          e         c        e
# 1  0.530923      6         O          P         O        P
# 2  0.662277      6         X          W         W        X
# 3  0.726610      6         e          c         c        e
# 4  0.590283      6         W          X         W        X
# 5  0.522442      6         P          O         O        P

# %% [markdown]
# ### Idem for the practice session

# %%
tr = 2
n_runs = 2

save_dir = '../designs'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.hstack(['PRACTICE']):
    designs_this_session = []
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in [1,2,4,5]:
        settings = get_settings(tr=tr)
        include_cue, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(12, settings['jitter'], ps=settings['ps'],
                                       stim_sets=stim_set,
                                       mr_design=False, include_cue=include_cue, practice=True)
        design['block'] = run
        designs_this_session.append(design)
    
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    fn = 'sub-' + str(subject_id).zfill(2) + '_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: PRACTICE, run: 1, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: PRACTICE, run: 2, cue: False
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: PRACTICE, run: 4, cue: True
# Settings:
#
#         Sessions: 2
#         Trials per run: 144
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*144 = 1152 seconds = 19.2 min
#         Total number of volumes necessary: 1+144*4 = 577 + warm-up pulses
# Subject: PRACTICE, run: 5, cue: True
# /Users/steven/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Stimuli/set order for this pp: [['j', 'm'], ['s', 'y'], ['u', 'n'], ['j', 'm'], ['s', 'y'], ['u', 'n']]
# sub-PRACTICE_design

# %%
design
# Out:
#     stimulus_set  correct_stim_lr  cue p_win_left p_win_right p_win_correct  \
# 0              1                0             0.7         0.3           0.7
# 1              2                0            0.65        0.35          0.65
# 2              0                1             0.2         0.8           0.8
# 3              1                1             0.3         0.7           0.7
# 4              2                1            0.35        0.65          0.65
# 5              2                1            0.35        0.65          0.65
# 6              1                0             0.7         0.3           0.7
# 7              1                1             0.3         0.7           0.7
# 8              0                0             0.8         0.2           0.8
# 9              0                0             0.8         0.2           0.8
# 10             2                0            0.65        0.35          0.65
# 11             0                1             0.2         0.8           0.8
# 0              2                1            0.35        0.65          0.65
# 1              0                1             0.2         0.8           0.8
# 2              1                1             0.3         0.7           0.7
# 3              2                0            0.65        0.35          0.65
# 4              2                1            0.35        0.65          0.65
# 5              0                1             0.2         0.8           0.8
# 6              0                0             0.8         0.2           0.8
# 7              1                1             0.3         0.7           0.7
# 8              1                0             0.7         0.3           0.7
# 9              0                0             0.8         0.2           0.8
# 10             2                0            0.65        0.35          0.65
# 11             1                0             0.7         0.3           0.7
# 0              5                1  ACC       0.35        0.65          0.65
# 1              3                0  ACC        0.8         0.2           0.8
# 2              3                1  ACC        0.2         0.8           0.8
# 3              3                1  SPD        0.2         0.8           0.8
# 4              4                1  SPD        0.3         0.7           0.7
# 5              5                0  SPD       0.65        0.35          0.65
# 6              5                0  ACC       0.65        0.35          0.65
# 7              4                0  SPD        0.7         0.3           0.7
# 8              5                1  ACC       0.35        0.65          0.65
# 9              3                0  SPD        0.8         0.2           0.8
# 10             4                0  ACC        0.7         0.3           0.7
# 11             4                1  ACC        0.3         0.7           0.7
# 0              3                0  ACC        0.8         0.2           0.8
# 1              5                1  SPD       0.35        0.65          0.65
# 2              4                1  ACC        0.3         0.7           0.7
# 3              5                0  SPD       0.65        0.35          0.65
# 4              5                1  ACC       0.35        0.65          0.65
# 5              5                0  ACC       0.65        0.35          0.65
# 6              4                0  SPD        0.7         0.3           0.7
# 7              4                1  SPD        0.3         0.7           0.7
# 8              3                1  ACC        0.2         0.8           0.8
# 9              3                0  ACC        0.8         0.2           0.8
# 10             3                1  SPD        0.2         0.8           0.8
# 11             4                0  ACC        0.7         0.3           0.7
#
#    p_win_incorrect  phase_1  phase_2  phase_3  phase_4  phase_5  phase_6  \
# 0              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 1             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 2              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 3              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 4             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 5             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 6              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 7              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 8              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 9              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 10            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 11             0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 0             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 1              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 2              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 3             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 4             0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 5              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 6              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 7              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 8              0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 9              0.2  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 10            0.35  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 11             0.3  -0.0001  -0.0001  -0.0001        2      0.5     0.75
# 0             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 6             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 7              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 8             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 9              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 10             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 11             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 0              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 1             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 2              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 3             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 4             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 5             0.35  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 6              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 7              0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 8              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 9              0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 10             0.2  -0.0001   0.7500  -0.0001        2      0.5     0.75
# 11             0.3  -0.0001   0.7500  -0.0001        2      0.5     0.75
#
#      phase_7  block stim_left stim_right stim_high stim_low
# 0   0.656003      1         s          y         s        y
# 1   0.522087      1         u          n         u        n
# 2   0.948796      1         m          j         j        m
# 3   0.658428      1         y          s         s        y
# 4   0.878230      1         n          u         u        n
# 5   0.803671      1         n          u         u        n
# 6   0.658863      1         s          y         s        y
# 7   0.656991      1         y          s         s        y
# 8   0.728479      1         j          m         j        m
# 9   0.951297      1         j          m         j        m
# 10  0.943079      1         u          n         u        n
# 11  0.638572      1         m          j         j        m
# 0   0.838739      2         n          u         u        n
# 1   0.851088      2         m          j         j        m
# 2   0.658315      2         y          s         s        y
# 3   0.591583      2         u          n         u        n
# 4   0.740728      2         n          u         u        n
# 5   0.653481      2         m          j         j        m
# 6   0.883223      2         j          m         j        m
# 7   0.887654      2         y          s         s        y
# 8   0.918913      2         s          y         s        y
# 9   0.798922      2         j          m         j        m
# 10  0.515394      2         u          n         u        n
# 11  0.704516      2         s          y         s        y
# 0   0.897967      4         n          u         u        n
# 1   0.701644      4         j          m         j        m
# 2   0.516646      4         m          j         j        m
# 3   0.764401      4         m          j         j        m
# 4   0.604971      4         y          s         s        y
# 5   0.890306      4         u          n         u        n
# 6   0.982406      4         u          n         u        n
# 7   0.930701      4         s          y         s        y
# 8   0.982553      4         n          u         u        n
# 9   0.628314      4         j          m         j        m
# 10  0.959320      4         s          y         s        y
# 11  0.875944      4         y          s         s        y
# 0   0.815420      5         j          m         j        m
# 1   0.605094      5         n          u         u        n
# 2   0.559230      5         y          s         s        y
# 3   0.867821      5         u          n         u        n
# 4   0.635970      5         n          u         u        n
# 5   0.811940      5         u          n         u        n
# 6   0.761280      5         s          y         s        y
# 7   0.734275      5         y          s         s        y
# 8   0.594341      5         m          j         j        m
# 9   0.514113      5         j          m         j        m
# 10  0.908342      5         m          j         j        m
# 11  0.565302      5         s          y         s        y

# %%
idx = design.block == 2

# %%
idx
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 0     True
# 1     True
# 2     True
# 3     True
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# Name: block, dtype: bool

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 0     True
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# 0    False
# 1    False
# 2    False
# 3    False
# Name: block, dtype: bool

# %%
1 < np.cumsum(idx) < 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-00310cffbfd9> in <module>()
# ----> 1 1 < np.cumsum(idx) < 2
#
# /Users/steven/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
idx = design.block == 1
#idx & np.cumsum(idx) < 4

# %%
idx = design.block==1
design.loc[idx].groupby(['stimulus_set'])[['stim_left', 'stim_right']].last().reset_index()[['stim_left', 'stim_right']].values.tolist()
# Out:
# [['m', 'j'], ['s', 'y'], ['n', 'u']]

# %%
design[['stim_left', 'stim_right']].values
# Out:
# array([['u', 'n'],
#        ['y', 's'],
#        ['n', 'u'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['u', 'n'],
#        ['n', 'u'],
#        ['n', 'u'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['u', 'n'],
#        ['y', 's'],
#        ['j', 'm'],
#        ['n', 'u'],
#        ['u', 'n'],
#        ['s', 'y'],
#        ['m', 'j'],
#        ['j', 'm'],
#        ['n', 'u'],
#        ['y', 's'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['n', 'u'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['j', 'm'],
#        ['s', 'y']], dtype=object)

# %%
design['stim_right'].uni
# Out:
# array(['n', 's', 'u', 'y', 'm', 'j'], dtype=object)
