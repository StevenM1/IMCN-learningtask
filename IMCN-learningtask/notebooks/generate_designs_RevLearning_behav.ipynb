# %%
from __future__ import division
import pandas as pd
import os
import numpy as np
import itertools
import matplotlib.pyplot as plt
# %matplotlib inline

from random import shuffle

# %% [markdown]
# # REVERSAL LEARNING TASK DESIGN FILE GENERATOR

# %% [markdown]
# # Settings

# %% [markdown]
# design for behavioral project of follwing 7T fMRI project
#
# - nr. blocks: 2 {2 runs of ca 16 min expected a TR of 2}
# - nr of trials: 128 (per block) = 256 in total
# - reversal point: after circa half of the trials but differently for each stimulus set
#
# - sessions!!! Make sure to create design files for both sessions

# %% [markdown]
# ### last edits
#
# - reversal range increased to 26, 38 [per stim_set] - hence, (54, 76) instead of (60,68) from old design
# - second session created
# - stimuli adjusted for both sessions
# - different reversal points for the different stimulus_sets
# - number of trials adjusted to 128 [see also for reversal point]
# - Phases_ renamed to phase names in final design generating loop (line 43)

# %% [markdown]
# #  TO DO
#
# - change symbols for practice  ?
#
#
#
# - make design for second session using galgolitsa alphabet √
# - adjust symbols √
# - ! will be created in preprocessing notebook ! Compute new 'Stim_high' 'Stim_low' columns that take into account the reversal

# %% [markdown]
# ### Creates design files for the instrumental learning task
#
# An experimental session containts two task, each of which is performed in three runs: 1. a vanilla instrumental learning task, and 2. a SAT-version of the task. Task order is counterbalanced, stimuli are updated between tasks. Stimuli are assigned a value randomly (i.e. also counterbalanced).
#
#
# ##### Design files are DataFrames with the following info per trial:
# 1. `stim_set`: Which stimulus set is presented? [0, 1, 2, 3, 4, 5, 6]
# 2. `correct_stim_lr`: What is the location (on the screen) of the winning stim? [0 = left, 1=right]
# 3. `p_win_left`: Probability of winning if left is chosen
# 4. `p_win_right'`: Probability of winning if right is chosen
# 5. `p_win_correct`: Probability of winning if correct answer is chosen
# 6. `p_win_incorrect`: Probability of winning if incorrect answer is chosen
# 7. `phase_x`: Duration for phase `x` (in s; see below)
# 8. `stim_left`, `stim_right`:  Stimuli that are presented left, right
# 9. `stim_high`, `stim_low`: Stimuli that correspond to the high, low probability of winning
#
# ##### Trial phases:
# 1. Fixation cross (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 2. Cue (0.75s)
# 3. Fixation cross (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 4. Stimulus (2s)
# 5. Stimulus choice (jittered timing) `[0.5, 0.75, 1.0, 1.25, 1.5s]`
# 6. Feedback (0.5s)
# 7. ITI (jittered timing) `[0.25, 0.5, ..., 3.25s]`
#
# The timings mentioned above are for the MR version of the SAT task. Without MR, the jittered fixation crosses are skipped, the stimulus duration is not fixed to 2 seconds but ends when the participant gave a response, and highlight of choice is a fixed duration. ITI is shortened but still jittered a bit.
#
# ##### Potential future options:
# 1. Pseudorandomize trial order;
# 2. Optimize design (have code for this)

# %%
def get_settings(tr=2, verbose=True):
    p_win = [[.8, .2], [.7, .3]]            # removed , [.65, .35]
    n_runs = 2
    n_sessions = 1
    if tr == 2:
        n_trials = 128   #128
        jitters = [0.5, 0.75, 1, 1.25, 1.5]
        volumes_per_trial = 4
    
    n_trials_per_stimset = n_trials/len(p_win)
    trial_duration = volumes_per_trial*tr                # trial duration 
    total_duration = trial_duration*n_trials
    total_duration_min = total_duration/60
    total_volumes = 1 + n_trials*volumes_per_trial
    
    if verbose:
        print('Settings:\n\n\
        Sessions: {n_sessions}\n\
        Trials per run: {n_trials}\n\
        Assuming a TR of {tr} seconds\n\
        Jitter options: {jitters} seconds\n\
        Total duration: {tr}*{trial_duration}*{n_trials} = {total_duration} seconds = {total_duration_min} min\n\
        Total number of volumes necessary: 1+{n_trials}*{volumes_per_trial} = {total_volumes} + warm-up pulses'.format(**locals()))
        
    return({'jitter': jitters,
            'n_trials': n_trials,
            'ps': p_win})

# %%
def generate_block_design(n_trials, jitters, 
                          ps,
                          stim_sets=[0,1],
                          reversal_n_trials = (10,20),
                          mr_design=True, 
                          include_cue=False, 
                          phase_durations=['jittered', 0.75, 'jittered', 2, 'jittered', 0.75, 'iti'],
                          trial_duration=8,
                          practice=False):
    """ Generates design for a single block.
    
    jitters: list of possible jitter durations, in seconds (e.g., [0.5, 1, 1.5])
    mr_design: bool. If False, all phases that are jittered are set to -1 and skipped in the experiment; iti is set lower
    include_cue: bool. If False, the cue phase duration will be set to -1.
    """
    correct_stim_lr = [0, 1]
    if include_cue:
        cues = ['SPD', 'ACC']
    else:
        cues = ['']
    combs = list(itertools.product(stim_sets, correct_stim_lr, cues))
    
    # make basic df
    design = pd.DataFrame(combs * int(np.ceil((n_trials/len(combs)))), 
                          columns=['stimulus_set', 'correct_stim_lr', 'cue_txt'])
    # randomize
    design = design.sample(frac=1).reset_index(drop=True)#.reset_index('trial_ID')
    n_trials_real = design.shape[0] 
    design = design.iloc[:n_trials]
    
    if not n_trials == n_trials_real:
        print('WARNING: not totally balanced (%d not a multitude of %d)' %(n_trials, len(combs)))
    
    
    # SM
    for set_nr, stim_set in enumerate(stim_sets):
        print(stim_set, set_nr)
        if reversal_n_trials is not None:
            # how many trials is this stimulus shown?
            n_trials_this_stimset = design.loc[design.stimulus_set == stim_set].shape[0]
            reversal = np.zeros(n_trials_this_stimset)

            # determine reversal points: it's somwhere between reversal_n_trials[0] and reversal_n_trials[1]
            reversal_point = np.random.uniform(reversal_n_trials[0], reversal_n_trials[1], 1).astype(int)[0]

            # set all values after reversal point to 1
            reversal[reversal_point:] = 1
        else:
            reversal = 0
        # append to design
        design.loc[design['stimulus_set'] == stim_set, 'reversal'] = reversal
   

    # Add probabilities (left/right and correct/incorrect - this is redundant, I know)
    design['p_win_left'] = None
    design['p_win_right'] = None
    design['p_win_correct'] = None
    design['p_win_incorrect'] = None
    for stim_set, p_win in zip(stim_sets, ps):
        p_win_high, p_win_low = p_win[0], p_win[1]           
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 0), 'p_win_left'] = p_win_high
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 1), 'p_win_right'] = p_win_high
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 1), 'p_win_left'] = p_win_low
        design.loc[(design.stimulus_set==stim_set) & (design.correct_stim_lr == 0), 'p_win_right'] = p_win_low
        design.loc[(design.stimulus_set==stim_set), 'p_win_correct'] = p_win_high
        design.loc[(design.stimulus_set==stim_set), 'p_win_incorrect'] = p_win_low
    
    reversal_idx = design['reversal'] == 1
    # swap left & right probabilities
    design.loc[reversal_idx, 'p_win_left'], design.loc[reversal_idx, 'p_win_right'] = design.loc[reversal_idx, 'p_win_right'].copy(), design.loc[reversal_idx, 'p_win_left'].copy()
            
            
    # Add phase durations
    for phase, duration in enumerate(phase_durations):
        col_key = 'phase_' + str(phase+1)
        if duration == 'jittered':
            design[col_key] = np.random.choice(jitters, size=n_trials, replace=True)
        elif duration == 'iti':
            iti_phase_col_key = 'phase_' + str(phase+1)
        else:
            design[col_key] = duration
    
    design[iti_phase_col_key] = trial_duration - design[[col for col in design.columns if 'phase' in col]].apply(sum, axis=1)

    
    if not mr_design:
        # remove jitters
        for phase, duration in enumerate(phase_durations):
            col_key = 'phase_' + str(phase+1)
            if duration == 'jittered':
                design[col_key] = -.0001
            # set iti to randomly sampled from [0.5, 1]
            if duration == 'iti':
                design[col_key] = np.random.uniform(0.5, 1, design.shape[0])
        # set choice highlight phase to fixed 0.5
        design['phase_5'] = 0.5

    if not include_cue:
        # always skip cue
        design['phase_2'] = -.0001
        
    if practice and include_cue:
        design.cue.iloc[0] = 'ACC'

    return(design)

# generate_block_design(18, [0, 1, 2])

# %%
def get_task_type(run, subject_id, is_practice=False, is_debug=False):    
    def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            return False
    
    if is_debug:
        if run > 3:
            include_cue = False
        else:
            include_cue = False                        # set to False for RLWM study
    elif is_practice:
        # start practice without cues
        if run <= 2:  
            include_cue = False
        else:
            include_cue = False                        # set to False for RLWM study

    elif is_number(subject_id):
        if (int(subject_id) % 2) == 0:
            if run > 3:
                include_cue = False
            else:
                include_cue = False                        # set to False for RLWM study
        else:
            if run > 3:
                include_cue = False                        # set to False for RLWM study
            else:
                include_cue = False
                
    # Return stimuli
    if run <= 4:
        stim_sets = [0,1]
    elif run > 4:
        stim_sets = [3,4]
            
    return include_cue, stim_sets

# %%
def counterbalance_stimuli(subject_id, all_sets=  [[['h', 'i'],     #Cc
                                                   ['X', 'e']],    #fx
                                                  [['o', 'K'],     #jN
                                                   ['Y', 'y']]]):    
                           
                           
                           
                           
                           
#                                                    [[['h', 'i'],     #Cc
#                                                    ['X', 'e'],     #Dg
#                                                    ['u', 'n']],    #fx
#                                                   [['o', 'K'],     #jN
#                                                    ['Y', 'y'],     #QJ
#                                                    ['P', 'A']],    #mM
#                                                   [['V', 'v'],     #RS
#                                                    ['J', 'B'],     #sT
# 
        import itertools
        from copy import deepcopy

        n_shifts = [0, 1,3]  # add more/less if counterbalancing error when generating designs 
                            # [0,1] crashed for >9 subjects
                            # [0, 1,3] works for 100 subjects
        rev_inner = [False, True]
        switch_sets = [False, True]

        cb_df = pd.DataFrame(list(itertools.product(switch_sets, n_shifts, rev_inner)),
                             columns=['switch_sets', 'n_shifts', 'rev_inner'])
        cb_df['pp'] = np.arange(1, cb_df.shape[0] + 1)
        for set_n in range(1, 13):
            cb_df['stim_%d' % set_n] = None

        for pp in cb_df['pp']:
            idx = cb_df.pp == pp
            switch_sets = cb_df.loc[idx, 'switch_sets'].iloc[0]
            reverse_inner = cb_df.loc[idx, 'rev_inner'].iloc[0]
            n_shifts = cb_df.loc[idx, 'n_shifts'].iloc[0]

            if switch_sets:
                sets = deepcopy([all_sets[2:], all_sets[:2]])
            else:
                sets = deepcopy([all_sets[:2], all_sets[2:]])

            sets_allocated = 0
            for set_n, set_ in enumerate(sets):
                for i in range(n_shifts):
                    set_.insert(len(set_), set_.pop(0))  # move first item to last place

                if reverse_inner:
                    set_ = [x[::-1] for x in set_]  # reverse inner order

                # print('pp %d, %d, %s' % (pp, set_n, set_))
                #### NB: you could just use set_ as a final result; the placing in the dataframe and then reverting
                # back to a nested list is definitely not necessary but may help clarify what's going on here...
                for to_allocate in [0, 1]:
                    for to_allocate_i in [0, 1]:
                        cb_df.loc[idx, 'stim_%d' % (sets_allocated + 1)] = set_[to_allocate][to_allocate_i]
                        sets_allocated += 1

        pp_zero_based = int(subject_id) - 1
        row_iloc = int(pp_zero_based - np.floor(pp_zero_based / 12) * 12)
        colnames = cb_df.columns
        stim_list = cb_df.iloc[row_iloc][[x for x in colnames if 'stim' in x]].values.tolist()
        stim_nested_list = [[stim_list[0 + y * 2], stim_list[1 + y * 2]] for y in range(4)] # BEFORE: in range(6)
        print('Stimuli/set order for this pp: %s' % stim_nested_list)
        return stim_nested_list

# %%
# from random import shuffle
# stim_sets = [['A', 'B'], ['J', 'K'], ['M', 'N'], ['O', 'P'],  ['W', 'X'], ['c', 'e']]
# shuffle(stim_sets)
# print(stim_sets)

# for block in len(run):
#     if run == '1':
#         return stim_set = block_stim[0][1]
#     if run == '2':
#         return stim_set = block_stim[2][3]
#     if run == '3':
#         return stim_set = block_stim[4][5]
#     else:
#         return stim_sets = block_stim[6][7]
# /

# %% [markdown]
# # Create session 1
#
# agathodaimon alphabeth
#  (1 = agathodaimon, 2 = galgolitsa)

# %%
def get_stimuli(subject_id, design):    
    if subject_id == 'PRACTICE':
        # The practice session always gets different stimuli
        stim_sets = [['j', 'm'], ['s', 'y'], ['u', 'n'], ['j', 'm'], ['s', 'y'], ['u', 'n']]
    else:
        stim_sets = [['h', 'i'],     #Cc
                    ['X', 'e'],     #Dg
#                     ['u', 'n'],    #fx
                    ['o', 'K'],     #jN
                    ['Y', 'y']]     #QJ

    if subject_id == 'DEBUG' or subject_id == 'PRACTICE':
        # just use counterbalancing order 1 for practice & debug
        subject_id = 1
    

       
    all_stim = counterbalance_stimuli(subject_id, all_sets=stim_sets)
    
    design['stim_left'] = None
    design['stim_right'] = None
    design['stim_high'] = None
    design['stim_low'] = None


    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        design.loc[idx_this_stim, 'stim_high'] = all_stim[i][0]
        design.loc[idx_this_stim, 'stim_low'] = all_stim[i][1]

    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        idx_this_stim_nonrev = (idx_this_stim) & (design.correct_stim_lr == 0)
        idx_this_stim_rev = (idx_this_stim) & (design.correct_stim_lr == 1)

        design.loc[idx_this_stim_nonrev, 'stim_left'] = design.loc[idx_this_stim_nonrev, 'stim_high']
        design.loc[idx_this_stim_nonrev, 'stim_right'] = design.loc[idx_this_stim_nonrev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_left'] = design.loc[idx_this_stim_rev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_right'] = design.loc[idx_this_stim_rev, 'stim_high']
   
    return design

# %%
tr = 2
n_subjects = 100
n_runs = 1      # set to one less than blocks you want 

save_dir = '../designs_reversal-learning'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.arange(1,n_subjects+1):
    designs_this_session = []
    print(subject_id)
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in range(1,n_runs*2+1):
        settings = get_settings(tr=tr)
#        _, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)

        stim_set = [0, 1]
        include_cue = False
        
        # reversals
        reversals = (26, 38)
        
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(settings['n_trials'],
                                       settings['jitter'], 
                                       ps=settings['ps'],
                                       
                                       reversal_n_trials=reversals,
                                       
                                       stim_sets=stim_set,
                                       mr_design=False, 
                                       include_cue=include_cue)
        design['block'] = run
        design['stimulus_set'] = design['stimulus_set'] + 2*(run-1)
        designs_this_session.append(design)
        
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    
    
    design.rename(columns={'phase_1': 'fix_cross_1',
                           'phase_2': 'cue',
                           'phase_3': 'fix_cross_2',
                           'phase_4': 'stimulus',
                           'phase_5': 'highlight',
                           'phase_6': 'feedback',
                           'phase_7': 'iti_posttrial'}, 
                  inplace=True)
    
    fn = 'sub-' + str(subject_id).zfill(3) + '_ses-1_task-reversal-learning_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 1, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 1, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-001_ses-1_task-reversal-learning_design
# 2
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 2, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 2, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-002_ses-1_task-reversal-learning_design
# 3
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 3, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 3, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-003_ses-1_task-reversal-learning_design
# 4
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 4, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 4, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-004_ses-1_task-reversal-learning_design
# 5
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 5, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 5, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-005_ses-1_task-reversal-learning_design
# 6
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 6, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 6, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-006_ses-1_task-reversal-learning_design
# 7
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 7, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 7, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-007_ses-1_task-reversal-learning_design
# 8
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 8, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 8, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-008_ses-1_task-reversal-learning_design
# 9
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 9, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 9, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-009_ses-1_task-reversal-learning_design
# 10
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 10, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 10, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-010_ses-1_task-reversal-learning_design
# 11
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 11, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 11, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-011_ses-1_task-reversal-learning_design
# 12
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 12, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 12, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-012_ses-1_task-reversal-learning_design
# 13
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 13, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 13, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-013_ses-1_task-reversal-learning_design
# 14
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 14, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 14, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-014_ses-1_task-reversal-learning_design
# 15
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 15, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 15, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-015_ses-1_task-reversal-learning_design
# 16
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 16, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 16, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-016_ses-1_task-reversal-learning_design
# 17
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 17, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 17, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-017_ses-1_task-reversal-learning_design
# 18
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 18, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 18, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-018_ses-1_task-reversal-learning_design
# 19
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 19, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 19, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-019_ses-1_task-reversal-learning_design
# 20
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 20, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 20, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-020_ses-1_task-reversal-learning_design
# 21
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 21, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 21, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-021_ses-1_task-reversal-learning_design
# 22
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 22, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 22, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-022_ses-1_task-reversal-learning_design
# 23
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 23, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 23, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-023_ses-1_task-reversal-learning_design
# 24
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 24, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 24, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-024_ses-1_task-reversal-learning_design
# 25
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 25, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 25, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-025_ses-1_task-reversal-learning_design
# 26
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 26, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 26, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-026_ses-1_task-reversal-learning_design
# 27
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 27, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 27, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-027_ses-1_task-reversal-learning_design
# 28
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 28, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 28, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-028_ses-1_task-reversal-learning_design
# 29
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 29, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 29, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-029_ses-1_task-reversal-learning_design
# 30
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 30, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 30, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-030_ses-1_task-reversal-learning_design
# 31
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 31, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 31, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-031_ses-1_task-reversal-learning_design
# 32
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 32, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 32, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-032_ses-1_task-reversal-learning_design
# 33
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 33, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 33, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-033_ses-1_task-reversal-learning_design
# 34
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 34, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 34, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-034_ses-1_task-reversal-learning_design
# 35
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 35, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 35, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-035_ses-1_task-reversal-learning_design
# 36
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 36, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 36, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-036_ses-1_task-reversal-learning_design
# 37
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 37, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 37, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-037_ses-1_task-reversal-learning_design
# 38
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 38, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 38, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-038_ses-1_task-reversal-learning_design
# 39
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 39, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 39, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-039_ses-1_task-reversal-learning_design
# 40
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 40, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 40, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-040_ses-1_task-reversal-learning_design
# 41
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 41, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 41, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-041_ses-1_task-reversal-learning_design
# 42
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 42, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 42, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-042_ses-1_task-reversal-learning_design
# 43
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 43, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 43, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-043_ses-1_task-reversal-learning_design
# 44
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 44, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 44, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-044_ses-1_task-reversal-learning_design
# 45
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 45, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 45, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-045_ses-1_task-reversal-learning_design
# 46
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 46, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 46, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-046_ses-1_task-reversal-learning_design
# 47
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 47, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 47, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-047_ses-1_task-reversal-learning_design
# 48
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 48, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 48, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-048_ses-1_task-reversal-learning_design
# 49
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 49, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 49, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-049_ses-1_task-reversal-learning_design
# 50
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 50, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 50, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-050_ses-1_task-reversal-learning_design
# 51
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 51, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 51, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-051_ses-1_task-reversal-learning_design
# 52
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 52, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 52, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-052_ses-1_task-reversal-learning_design
# 53
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 53, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 53, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-053_ses-1_task-reversal-learning_design
# 54
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 54, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 54, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-054_ses-1_task-reversal-learning_design
# 55
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 55, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 55, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-055_ses-1_task-reversal-learning_design
# 56
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 56, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 56, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-056_ses-1_task-reversal-learning_design
# 57
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 57, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 57, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-057_ses-1_task-reversal-learning_design
# 58
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 58, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 58, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-058_ses-1_task-reversal-learning_design
# 59
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 59, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 59, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-059_ses-1_task-reversal-learning_design
# 60
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 60, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
# ...
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 81, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 81, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-081_ses-1_task-reversal-learning_design
# 82
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 82, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 82, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-082_ses-1_task-reversal-learning_design
# 83
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 83, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 83, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-083_ses-1_task-reversal-learning_design
# 84
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 84, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 84, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-084_ses-1_task-reversal-learning_design
# 85
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 85, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 85, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-085_ses-1_task-reversal-learning_design
# 86
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 86, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 86, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-086_ses-1_task-reversal-learning_design
# 87
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 87, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 87, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-087_ses-1_task-reversal-learning_design
# 88
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 88, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 88, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-088_ses-1_task-reversal-learning_design
# 89
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 89, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 89, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-089_ses-1_task-reversal-learning_design
# 90
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 90, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 90, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-090_ses-1_task-reversal-learning_design
# 91
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 91, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 91, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['o', 'K'], ['Y', 'y'], ['h', 'i'], ['X', 'e']]
# sub-091_ses-1_task-reversal-learning_design
# 92
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 92, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 92, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['K', 'o'], ['y', 'Y'], ['i', 'h'], ['e', 'X']]
# sub-092_ses-1_task-reversal-learning_design
# 93
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 93, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 93, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-093_ses-1_task-reversal-learning_design
# 94
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 94, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 94, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-094_ses-1_task-reversal-learning_design
# 95
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 95, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 95, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['Y', 'y'], ['o', 'K'], ['X', 'e'], ['h', 'i']]
# sub-095_ses-1_task-reversal-learning_design
# 96
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 96, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 96, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['y', 'Y'], ['K', 'o'], ['e', 'X'], ['i', 'h']]
# sub-096_ses-1_task-reversal-learning_design
# 97
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 97, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 97, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['o', 'K'], ['Y', 'y']]
# sub-097_ses-1_task-reversal-learning_design
# 98
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 98, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 98, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['i', 'h'], ['e', 'X'], ['K', 'o'], ['y', 'Y']]
# sub-098_ses-1_task-reversal-learning_design
# 99
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 99, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 99, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['X', 'e'], ['h', 'i'], ['Y', 'y'], ['o', 'K']]
# sub-099_ses-1_task-reversal-learning_design
# 100
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 100, run: 1, cue: False
# (0, 0)
# (1, 1)
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.0666666667 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 100, run: 2, cue: False
# (0, 0)
# (1, 1)
# Stimuli/set order for this pp: [['e', 'X'], ['i', 'h'], ['y', 'Y'], ['K', 'o']]
# sub-100_ses-1_task-reversal-learning_design

# %%
## np.mean(design['iti_posttrial'])

# %%
#print all lines 

#show all columns
with pd.option_context('display.max_rows', None):
    display(design)
# Out:
#      stimulus_set  correct_stim_lr cue_txt  reversal p_win_left p_win_right  \
# 0               0                0               0.0        0.8         0.2
# 1               0                1               0.0        0.2         0.8
# 2               1                1               0.0        0.3         0.7
# 3               1                0               0.0        0.7         0.3
# 4               1                0               0.0        0.7         0.3
# 5               0                0               0.0        0.8         0.2
# 6               0                1               0.0        0.2         0.8
# 7               0                1               0.0        0.2         0.8
# 8               0                0               0.0        0.8         0.2
# 9               0                1               0.0        0.2         0.8
# 10              0                0               0.0        0.8         0.2
# 11              1                0               0.0        0.7         0.3
# 12              1                1               0.0        0.3         0.7
# 13              0                1               0.0        0.2         0.8
# 14              1                1               0.0        0.3         0.7
# 15              1                1               0.0        0.3         0.7
# 16              1                0               0.0        0.7         0.3
# 17              1                1               0.0        0.3         0.7
# 18              0                1               0.0        0.2         0.8
# 19              1                1               0.0        0.3         0.7
# 20              0                1               0.0        0.2         0.8
# 21              1                1               0.0        0.3         0.7
# 22              1                0               0.0        0.7         0.3
# 23              1                0               0.0        0.7         0.3
# 24              0                1               0.0        0.2         0.8
# 25              0                0               0.0        0.8         0.2
# 26              0                0               0.0        0.8         0.2
# 27              0                0               0.0        0.8         0.2
# 28              1                1               0.0        0.3         0.7
# 29              0                1               0.0        0.2         0.8
# 30              0                1               0.0        0.2         0.8
# 31              1                1               0.0        0.3         0.7
# 32              0                0               0.0        0.8         0.2
# 33              0                0               0.0        0.8         0.2
# 34              1                0               0.0        0.7         0.3
# 35              1                0               0.0        0.7         0.3
# 36              0                1               0.0        0.2         0.8
# 37              1                0               0.0        0.7         0.3
# 38              1                0               0.0        0.7         0.3
# 39              0                0               0.0        0.8         0.2
# 40              1                0               0.0        0.7         0.3
# 41              0                0               0.0        0.8         0.2
# 42              1                0               0.0        0.7         0.3
# 43              0                0               0.0        0.8         0.2
# 44              1                1               0.0        0.3         0.7
# 45              1                0               0.0        0.7         0.3
# 46              0                1               0.0        0.2         0.8
# 47              0                0               0.0        0.8         0.2
# 48              0                1               0.0        0.2         0.8
# 49              0                1               0.0        0.2         0.8
# 50              0                1               0.0        0.2         0.8
# 51              0                1               0.0        0.2         0.8
# 52              0                0               0.0        0.8         0.2
# 53              1                1               0.0        0.3         0.7
# 54              1                1               0.0        0.3         0.7
# 55              0                1               0.0        0.2         0.8
# 56              0                1               0.0        0.2         0.8
# 57              1                1               0.0        0.3         0.7
# 58              0                0               0.0        0.8         0.2
# 59              1                1               0.0        0.3         0.7
# 60              1                0               0.0        0.7         0.3
# 61              0                0               0.0        0.8         0.2
# 62              1                1               0.0        0.3         0.7
# 63              0                0               0.0        0.8         0.2
# 64              1                0               0.0        0.7         0.3
# 65              1                0               0.0        0.7         0.3
# 66              0                0               1.0        0.2         0.8
# 67              0                0               1.0        0.2         0.8
# 68              1                0               0.0        0.7         0.3
# 69              1                0               1.0        0.3         0.7
# 70              0                1               1.0        0.8         0.2
# 71              1                0               1.0        0.3         0.7
# 72              1                1               1.0        0.7         0.3
# 73              0                0               1.0        0.2         0.8
# 74              0                0               1.0        0.2         0.8
# 75              0                1               1.0        0.8         0.2
# 76              1                1               1.0        0.7         0.3
# 77              1                0               1.0        0.3         0.7
# 78              0                0               1.0        0.2         0.8
# 79              1                1               1.0        0.7         0.3
# 80              1                0               1.0        0.3         0.7
# 81              0                1               1.0        0.8         0.2
# 82              0                0               1.0        0.2         0.8
# 83              1                0               1.0        0.3         0.7
# 84              0                1               1.0        0.8         0.2
# 85              0                0               1.0        0.2         0.8
# 86              1                1               1.0        0.7         0.3
# 87              0                0               1.0        0.2         0.8
# 88              1                0               1.0        0.3         0.7
# 89              1                1               1.0        0.7         0.3
# 90              0                1               1.0        0.8         0.2
# 91              0                0               1.0        0.2         0.8
# 92              1                0               1.0        0.3         0.7
# 93              1                0               1.0        0.3         0.7
# 94              0                1               1.0        0.8         0.2
# 95              0                1               1.0        0.8         0.2
# 96              1                0               1.0        0.3         0.7
# 97              0                0               1.0        0.2         0.8
# 98              1                1               1.0        0.7         0.3
# 99              0                0               1.0        0.2         0.8
# 100             0                1               1.0        0.8         0.2
# 101             0                1               1.0        0.8         0.2
# 102             1                1               1.0        0.7         0.3
# 103             1                1               1.0        0.7         0.3
# 104             0                1               1.0        0.8         0.2
# 105             1                1               1.0        0.7         0.3
# 106             0                0               1.0        0.2         0.8
# 107             1                1               1.0        0.7         0.3
# 108             1                1               1.0        0.7         0.3
# 109             1                0               1.0        0.3         0.7
# 110             1                0               1.0        0.3         0.7
# 111             0                1               1.0        0.8         0.2
# 112             1                1               1.0        0.7         0.3
# 113             1                1               1.0        0.7         0.3
# 114             0                1               1.0        0.8         0.2
# 115             1                1               1.0        0.7         0.3
# 116             0                1               1.0        0.8         0.2
# 117             0                1               1.0        0.8         0.2
# 118             1                1               1.0        0.7         0.3
# 119             0                0               1.0        0.2         0.8
# 120             1                0               1.0        0.3         0.7
# 121             1                0               1.0        0.3         0.7
# 122             1                0               1.0        0.3         0.7
# 123             0                0               1.0        0.2         0.8
# 124             1                1               1.0        0.7         0.3
# 125             1                0               1.0        0.3         0.7
# 126             0                0               1.0        0.2         0.8
# 127             1                1               1.0        0.7         0.3
# 0               2                0               0.0        0.8         0.2
# 1               2                0               0.0        0.8         0.2
# 2               3                1               0.0        0.3         0.7
# 3               3                1               0.0        0.3         0.7
# 4               3                0               0.0        0.7         0.3
# 5               3                0               0.0        0.7         0.3
# 6               3                1               0.0        0.3         0.7
# 7               2                1               0.0        0.2         0.8
# 8               2                1               0.0        0.2         0.8
# 9               2                0               0.0        0.8         0.2
# 10              3                1               0.0        0.3         0.7
# 11              2                0               0.0        0.8         0.2
# 12              2                1               0.0        0.2         0.8
# 13              3                1               0.0        0.3         0.7
# 14              2                1               0.0        0.2         0.8
# 15              2                1               0.0        0.2         0.8
# 16              3                1               0.0        0.3         0.7
# 17              3                0               0.0        0.7         0.3
# 18              2                1               0.0        0.2         0.8
# 19              3                0               0.0        0.7         0.3
# 20              2                1               0.0        0.2         0.8
# 21              3                1               0.0        0.3         0.7
# 22              2                1               0.0        0.2         0.8
# 23              3                0               0.0        0.7         0.3
# 24              2                0               0.0        0.8         0.2
# 25              3                1               0.0        0.3         0.7
# 26              2                1               0.0        0.2         0.8
# 27              2                0               0.0        0.8         0.2
# 28              2                0               0.0        0.8         0.2
# 29              3                1               0.0        0.3         0.7
# 30              2                1               0.0        0.2         0.8
# 31              3                0               0.0        0.7         0.3
# 32              2                0               0.0        0.8         0.2
# 33              2                1               0.0        0.2         0.8
# 34              2                1               0.0        0.2         0.8
# 35              3                1               0.0        0.3         0.7
# 36              2                0               0.0        0.8         0.2
# 37              2                1               0.0        0.2         0.8
# 38              3                1               0.0        0.3         0.7
# 39              2                0               0.0        0.8         0.2
# 40              2                0               0.0        0.8         0.2
# 41              3                1               0.0        0.3         0.7
# 42              3                1               0.0        0.3         0.7
# 43              3                1               0.0        0.3         0.7
# 44              3                0               0.0        0.7         0.3
# 45              2                0               0.0        0.8         0.2
# 46              3                1               0.0        0.3         0.7
# 47              3                0               0.0        0.7         0.3
# 48              3                1               0.0        0.3         0.7
# 49              3                0               0.0        0.7         0.3
# 50              2                0               0.0        0.8         0.2
# 51              3                0               0.0        0.7         0.3
# 52              3                1               0.0        0.3         0.7
# 53              2                0               0.0        0.8         0.2
# 54              2                1               0.0        0.2         0.8
# 55              3                0               0.0        0.7         0.3
# 56              2                0               0.0        0.8         0.2
# 57              2                1               1.0        0.8         0.2
# 58              3                1               0.0        0.3         0.7
# 59              3                0               0.0        0.7         0.3
# 60              2                1               1.0        0.8         0.2
# 61              3                1               0.0        0.3         0.7
# 62              3                1               0.0        0.3         0.7
# 63              3                0               0.0        0.7         0.3
# 64              2                1               1.0        0.8         0.2
# 65              2                0               1.0        0.2         0.8
# 66              3                0               0.0        0.7         0.3
# 67              3                0               0.0        0.7         0.3
# 68              2                1               1.0        0.8         0.2
# 69              3                1               0.0        0.3         0.7
# 70              2                1               1.0        0.8         0.2
# 71              3                0               1.0        0.3         0.7
# 72              2                0               1.0        0.2         0.8
# 73              3                1               1.0        0.7         0.3
# 74              3                0               1.0        0.3         0.7
# 75              3                0               1.0        0.3         0.7
# 76              2                1               1.0        0.8         0.2
# 77              2                0               1.0        0.2         0.8
# 78              2                1               1.0        0.8         0.2
# 79              3                1               1.0        0.7         0.3
# 80              3                0               1.0        0.3         0.7
# 81              2                0               1.0        0.2         0.8
# 82              2                1               1.0        0.8         0.2
# 83              2                1               1.0        0.8         0.2
# 84              2                0               1.0        0.2         0.8
# 85              3                0               1.0        0.3         0.7
# 86              2                1               1.0        0.8         0.2
# 87              3                1               1.0        0.7         0.3
# 88              3                1               1.0        0.7         0.3
# 89              3                0               1.0        0.3         0.7
# 90              2                1               1.0        0.8         0.2
# 91              2                1               1.0        0.8         0.2
# 92              3                0               1.0        0.3         0.7
# 93              3                0               1.0        0.3         0.7
# 94              2                1               1.0        0.8         0.2
# 95              3                0               1.0        0.3         0.7
# 96              3                0               1.0        0.3         0.7
# 97              2                0               1.0        0.2         0.8
# 98              3                1               1.0        0.7         0.3
# 99              3                0               1.0        0.3         0.7
# 100             3                1               1.0        0.7         0.3
# 101             3                0               1.0        0.3         0.7
# 102             3                0               1.0        0.3         0.7
# 103             3                0               1.0        0.3         0.7
# 104             3                1               1.0        0.7         0.3
# 105             2                1               1.0        0.8         0.2
# 106             3                1               1.0        0.7         0.3
# 107             2                1               1.0        0.8         0.2
# 108             2                0               1.0        0.2         0.8
# 109             2                0               1.0        0.2         0.8
# 110             2                0               1.0        0.2         0.8
# 111             2                0               1.0        0.2         0.8
# 112             2                0               1.0        0.2         0.8
# 113             2                1               1.0        0.8         0.2
# 114             3                0               1.0        0.3         0.7
# 115             2                0               1.0        0.2         0.8
# 116             2                0               1.0        0.2         0.8
# 117             3                1               1.0        0.7         0.3
# 118             3                1               1.0        0.7         0.3
# 119             2                1               1.0        0.8         0.2
# 120             2                0               1.0        0.2         0.8
# 121             3                1               1.0        0.7         0.3
# 122             2                0               1.0        0.2         0.8
# 123             2                1               1.0        0.8         0.2
# 124             2                0               1.0        0.2         0.8
# 125             3                0               1.0        0.3         0.7
# 126             2                0               1.0        0.2         0.8
# 127             3                0               1.0        0.3         0.7
#
#     p_win_correct p_win_incorrect  fix_cross_1     cue  fix_cross_2  stimulus  \
# 0             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 1             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 2             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 3             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 4             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 5             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 6             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 7             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 8             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 9             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 10            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 11            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 12            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 13            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 14            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 15            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 16            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 17            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 18            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 19            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 20            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 21            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 22            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 23            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 24            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 25            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 26            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 27            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 28            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 29            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 30            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 31            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 32            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 33            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 34            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 35            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 36            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 37            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 38            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 39            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 40            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 41            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 42            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 43            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 44            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 45            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 46            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 47            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 48            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 49            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 50            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 51            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 52            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 53            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 54            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 55            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 56            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 57            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 58            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 59            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 60            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 61            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 62            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 63            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 64            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 65            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 66            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 67            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 68            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 69            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 70            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 71            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 72            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 73            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 74            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 75            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 76            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 77            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 78            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 79            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 80            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 81            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 82            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 83            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 84            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 85            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 86            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 87            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 88            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 89            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 90            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 91            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 92            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 93            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 94            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 95            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 96            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 97            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 98            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 99            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 100           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 101           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 102           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 103           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 104           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 105           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 106           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 107           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 108           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 109           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 110           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 111           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 112           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 113           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 114           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 115           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 116           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 117           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 118           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 119           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 120           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 121           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 122           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 123           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 124           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 125           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 126           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 127           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 0             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 1             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 2             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 3             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 4             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 5             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 6             0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 7             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 8             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 9             0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 10            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 11            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 12            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 13            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 14            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 15            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 16            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 17            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 18            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 19            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 20            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 21            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 22            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 23            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 24            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 25            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 26            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 27            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 28            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 29            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 30            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 31            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 32            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 33            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 34            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 35            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 36            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 37            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 38            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 39            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 40            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 41            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 42            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 43            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 44            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 45            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 46            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 47            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 48            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 49            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 50            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 51            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 52            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 53            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 54            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 55            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 56            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 57            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 58            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 59            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 60            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 61            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 62            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 63            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 64            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 65            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 66            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 67            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 68            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 69            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 70            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 71            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 72            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 73            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 74            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 75            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 76            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 77            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 78            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 79            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 80            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 81            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 82            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 83            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 84            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 85            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 86            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 87            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 88            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 89            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 90            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 91            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 92            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 93            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 94            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 95            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 96            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 97            0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 98            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 99            0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 100           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 101           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 102           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 103           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 104           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 105           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 106           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 107           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 108           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 109           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 110           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 111           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 112           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 113           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 114           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 115           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 116           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 117           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 118           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 119           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 120           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 121           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 122           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 123           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 124           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 125           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 126           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 127           0.7             0.3      -0.0001 -0.0001      -0.0001         2
#
#      highlight  feedback  iti_posttrial  block stim_left stim_right stim_high  \
# 0          0.5      0.75       0.934636      1         e          X         e
# 1          0.5      0.75       0.943830      1         X          e         e
# 2          0.5      0.75       0.660877      1         h          i         i
# 3          0.5      0.75       0.838227      1         i          h         i
# 4          0.5      0.75       0.586646      1         i          h         i
# 5          0.5      0.75       0.654744      1         e          X         e
# 6          0.5      0.75       0.793930      1         X          e         e
# 7          0.5      0.75       0.858111      1         X          e         e
# 8          0.5      0.75       0.588453      1         e          X         e
# 9          0.5      0.75       0.551439      1         X          e         e
# 10         0.5      0.75       0.909678      1         e          X         e
# 11         0.5      0.75       0.513942      1         i          h         i
# 12         0.5      0.75       0.639743      1         h          i         i
# 13         0.5      0.75       0.619242      1         X          e         e
# 14         0.5      0.75       0.761461      1         h          i         i
# 15         0.5      0.75       0.617287      1         h          i         i
# 16         0.5      0.75       0.713510      1         i          h         i
# 17         0.5      0.75       0.795411      1         h          i         i
# 18         0.5      0.75       0.627449      1         X          e         e
# 19         0.5      0.75       0.986456      1         h          i         i
# 20         0.5      0.75       0.684431      1         X          e         e
# 21         0.5      0.75       0.843384      1         h          i         i
# 22         0.5      0.75       0.720311      1         i          h         i
# 23         0.5      0.75       0.792101      1         i          h         i
# 24         0.5      0.75       0.827458      1         X          e         e
# 25         0.5      0.75       0.950820      1         e          X         e
# 26         0.5      0.75       0.595906      1         e          X         e
# 27         0.5      0.75       0.877626      1         e          X         e
# 28         0.5      0.75       0.601999      1         h          i         i
# 29         0.5      0.75       0.895559      1         X          e         e
# 30         0.5      0.75       0.815820      1         X          e         e
# 31         0.5      0.75       0.711420      1         h          i         i
# 32         0.5      0.75       0.610517      1         e          X         e
# 33         0.5      0.75       0.927953      1         e          X         e
# 34         0.5      0.75       0.769614      1         i          h         i
# 35         0.5      0.75       0.871570      1         i          h         i
# 36         0.5      0.75       0.929393      1         X          e         e
# 37         0.5      0.75       0.733272      1         i          h         i
# 38         0.5      0.75       0.509774      1         i          h         i
# 39         0.5      0.75       0.772291      1         e          X         e
# 40         0.5      0.75       0.772826      1         i          h         i
# 41         0.5      0.75       0.746047      1         e          X         e
# 42         0.5      0.75       0.852873      1         i          h         i
# 43         0.5      0.75       0.765559      1         e          X         e
# 44         0.5      0.75       0.517966      1         h          i         i
# 45         0.5      0.75       0.798630      1         i          h         i
# 46         0.5      0.75       0.758066      1         X          e         e
# 47         0.5      0.75       0.627164      1         e          X         e
# 48         0.5      0.75       0.925680      1         X          e         e
# 49         0.5      0.75       0.506005      1         X          e         e
# 50         0.5      0.75       0.974011      1         X          e         e
# 51         0.5      0.75       0.732016      1         X          e         e
# 52         0.5      0.75       0.944949      1         e          X         e
# 53         0.5      0.75       0.790861      1         h          i         i
# 54         0.5      0.75       0.544290      1         h          i         i
# 55         0.5      0.75       0.576208      1         X          e         e
# 56         0.5      0.75       0.952224      1         X          e         e
# 57         0.5      0.75       0.815301      1         h          i         i
# 58         0.5      0.75       0.502417      1         e          X         e
# 59         0.5      0.75       0.607206      1         h          i         i
# 60         0.5      0.75       0.531293      1         i          h         i
# 61         0.5      0.75       0.649920      1         e          X         e
# 62         0.5      0.75       0.933166      1         h          i         i
# 63         0.5      0.75       0.504303      1         e          X         e
# 64         0.5      0.75       0.564340      1         i          h         i
# 65         0.5      0.75       0.582855      1         i          h         i
# 66         0.5      0.75       0.911938      1         e          X         e
# 67         0.5      0.75       0.878592      1         e          X         e
# 68         0.5      0.75       0.714574      1         i          h         i
# 69         0.5      0.75       0.566801      1         i          h         i
# 70         0.5      0.75       0.695896      1         X          e         e
# 71         0.5      0.75       0.850345      1         i          h         i
# 72         0.5      0.75       0.801623      1         h          i         i
# 73         0.5      0.75       0.794132      1         e          X         e
# 74         0.5      0.75       0.708952      1         e          X         e
# 75         0.5      0.75       0.849352      1         X          e         e
# 76         0.5      0.75       0.594822      1         h          i         i
# 77         0.5      0.75       0.973910      1         i          h         i
# 78         0.5      0.75       0.997503      1         e          X         e
# 79         0.5      0.75       0.733778      1         h          i         i
# 80         0.5      0.75       0.989269      1         i          h         i
# 81         0.5      0.75       0.621068      1         X          e         e
# 82         0.5      0.75       0.558111      1         e          X         e
# ...
# 107        0.5      0.75       0.706848      1         h          i         i
# 108        0.5      0.75       0.671789      1         h          i         i
# 109        0.5      0.75       0.825680      1         i          h         i
# 110        0.5      0.75       0.649404      1         i          h         i
# 111        0.5      0.75       0.884996      1         X          e         e
# 112        0.5      0.75       0.599525      1         h          i         i
# 113        0.5      0.75       0.760034      1         h          i         i
# 114        0.5      0.75       0.647907      1         X          e         e
# 115        0.5      0.75       0.621353      1         h          i         i
# 116        0.5      0.75       0.747248      1         X          e         e
# 117        0.5      0.75       0.731063      1         X          e         e
# 118        0.5      0.75       0.837491      1         h          i         i
# 119        0.5      0.75       0.578088      1         e          X         e
# 120        0.5      0.75       0.968083      1         i          h         i
# 121        0.5      0.75       0.603453      1         i          h         i
# 122        0.5      0.75       0.896058      1         i          h         i
# 123        0.5      0.75       0.619953      1         e          X         e
# 124        0.5      0.75       0.887119      1         h          i         i
# 125        0.5      0.75       0.645183      1         i          h         i
# 126        0.5      0.75       0.571444      1         e          X         e
# 127        0.5      0.75       0.643127      1         h          i         i
# 0          0.5      0.75       0.675151      2         y          Y         y
# 1          0.5      0.75       0.768816      2         y          Y         y
# 2          0.5      0.75       0.581427      2         o          K         K
# 3          0.5      0.75       0.612110      2         o          K         K
# 4          0.5      0.75       0.861330      2         K          o         K
# 5          0.5      0.75       0.720853      2         K          o         K
# 6          0.5      0.75       0.839322      2         o          K         K
# 7          0.5      0.75       0.715473      2         Y          y         y
# 8          0.5      0.75       0.724947      2         Y          y         y
# 9          0.5      0.75       0.912481      2         y          Y         y
# 10         0.5      0.75       0.741174      2         o          K         K
# 11         0.5      0.75       0.736129      2         y          Y         y
# 12         0.5      0.75       0.588029      2         Y          y         y
# 13         0.5      0.75       0.837026      2         o          K         K
# 14         0.5      0.75       0.689988      2         Y          y         y
# 15         0.5      0.75       0.660994      2         Y          y         y
# 16         0.5      0.75       0.752844      2         o          K         K
# 17         0.5      0.75       0.896946      2         K          o         K
# 18         0.5      0.75       0.870262      2         Y          y         y
# 19         0.5      0.75       0.835495      2         K          o         K
# 20         0.5      0.75       0.661727      2         Y          y         y
# 21         0.5      0.75       0.587570      2         o          K         K
# 22         0.5      0.75       0.556168      2         Y          y         y
# 23         0.5      0.75       0.886348      2         K          o         K
# 24         0.5      0.75       0.538676      2         y          Y         y
# 25         0.5      0.75       0.860174      2         o          K         K
# 26         0.5      0.75       0.727973      2         Y          y         y
# 27         0.5      0.75       0.947223      2         y          Y         y
# 28         0.5      0.75       0.770563      2         y          Y         y
# 29         0.5      0.75       0.873766      2         o          K         K
# 30         0.5      0.75       0.767770      2         Y          y         y
# 31         0.5      0.75       0.694222      2         K          o         K
# 32         0.5      0.75       0.833372      2         y          Y         y
# 33         0.5      0.75       0.695137      2         Y          y         y
# 34         0.5      0.75       0.737014      2         Y          y         y
# 35         0.5      0.75       0.721127      2         o          K         K
# 36         0.5      0.75       0.879711      2         y          Y         y
# 37         0.5      0.75       0.882775      2         Y          y         y
# 38         0.5      0.75       0.800862      2         o          K         K
# 39         0.5      0.75       0.522883      2         y          Y         y
# 40         0.5      0.75       0.967365      2         y          Y         y
# 41         0.5      0.75       0.864692      2         o          K         K
# 42         0.5      0.75       0.652283      2         o          K         K
# 43         0.5      0.75       0.885169      2         o          K         K
# 44         0.5      0.75       0.532935      2         K          o         K
# 45         0.5      0.75       0.916570      2         y          Y         y
# 46         0.5      0.75       0.847722      2         o          K         K
# 47         0.5      0.75       0.759914      2         K          o         K
# 48         0.5      0.75       0.701993      2         o          K         K
# 49         0.5      0.75       0.799738      2         K          o         K
# 50         0.5      0.75       0.878051      2         y          Y         y
# 51         0.5      0.75       0.953607      2         K          o         K
# 52         0.5      0.75       0.641926      2         o          K         K
# 53         0.5      0.75       0.555390      2         y          Y         y
# 54         0.5      0.75       0.719907      2         Y          y         y
# 55         0.5      0.75       0.686799      2         K          o         K
# 56         0.5      0.75       0.631470      2         y          Y         y
# 57         0.5      0.75       0.922890      2         Y          y         y
# 58         0.5      0.75       0.914140      2         o          K         K
# 59         0.5      0.75       0.733404      2         K          o         K
# 60         0.5      0.75       0.842878      2         Y          y         y
# 61         0.5      0.75       0.566468      2         o          K         K
# 62         0.5      0.75       0.541723      2         o          K         K
# 63         0.5      0.75       0.920592      2         K          o         K
# 64         0.5      0.75       0.806620      2         Y          y         y
# 65         0.5      0.75       0.920096      2         y          Y         y
# 66         0.5      0.75       0.787052      2         K          o         K
# 67         0.5      0.75       0.770151      2         K          o         K
# 68         0.5      0.75       0.524250      2         Y          y         y
# 69         0.5      0.75       0.957962      2         o          K         K
# 70         0.5      0.75       0.730892      2         Y          y         y
# 71         0.5      0.75       0.698460      2         K          o         K
# 72         0.5      0.75       0.516665      2         y          Y         y
# 73         0.5      0.75       0.731564      2         o          K         K
# 74         0.5      0.75       0.717364      2         K          o         K
# 75         0.5      0.75       0.705907      2         K          o         K
# 76         0.5      0.75       0.566521      2         Y          y         y
# 77         0.5      0.75       0.670317      2         y          Y         y
# 78         0.5      0.75       0.711610      2         Y          y         y
# 79         0.5      0.75       0.523090      2         o          K         K
# 80         0.5      0.75       0.873213      2         K          o         K
# 81         0.5      0.75       0.650363      2         y          Y         y
# 82         0.5      0.75       0.973350      2         Y          y         y
# 83         0.5      0.75       0.671800      2         Y          y         y
# 84         0.5      0.75       0.920794      2         y          Y         y
# 85         0.5      0.75       0.571558      2         K          o         K
# 86         0.5      0.75       0.574973      2         Y          y         y
# 87         0.5      0.75       0.804682      2         o          K         K
# 88         0.5      0.75       0.898323      2         o          K         K
# 89         0.5      0.75       0.686287      2         K          o         K
# 90         0.5      0.75       0.680386      2         Y          y         y
# 91         0.5      0.75       0.924041      2         Y          y         y
# 92         0.5      0.75       0.743358      2         K          o         K
# 93         0.5      0.75       0.732197      2         K          o         K
# 94         0.5      0.75       0.521896      2         Y          y         y
# 95         0.5      0.75       0.765839      2         K          o         K
# 96         0.5      0.75       0.804010      2         K          o         K
# 97         0.5      0.75       0.738588      2         y          Y         y
# 98         0.5      0.75       0.935745      2         o          K         K
# 99         0.5      0.75       0.925359      2         K          o         K
# 100        0.5      0.75       0.965797      2         o          K         K
# 101        0.5      0.75       0.697015      2         K          o         K
# 102        0.5      0.75       0.852044      2         K          o         K
# 103        0.5      0.75       0.859169      2         K          o         K
# 104        0.5      0.75       0.721368      2         o          K         K
# 105        0.5      0.75       0.925290      2         Y          y         y
# 106        0.5      0.75       0.560517      2         o          K         K
# 107        0.5      0.75       0.505587      2         Y          y         y
# 108        0.5      0.75       0.906052      2         y          Y         y
# 109        0.5      0.75       0.514058      2         y          Y         y
# 110        0.5      0.75       0.850127      2         y          Y         y
# 111        0.5      0.75       0.764729      2         y          Y         y
# 112        0.5      0.75       0.590882      2         y          Y         y
# 113        0.5      0.75       0.970131      2         Y          y         y
# 114        0.5      0.75       0.581587      2         K          o         K
# 115        0.5      0.75       0.507625      2         y          Y         y
# 116        0.5      0.75       0.557751      2         y          Y         y
# 117        0.5      0.75       0.805292      2         o          K         K
# 118        0.5      0.75       0.928119      2         o          K         K
# 119        0.5      0.75       0.987337      2         Y          y         y
# 120        0.5      0.75       0.661073      2         y          Y         y
# 121        0.5      0.75       0.630734      2         o          K         K
# 122        0.5      0.75       0.838429      2         y          Y         y
# 123        0.5      0.75       0.984837      2         Y          y         y
# 124        0.5      0.75       0.915757      2         y          Y         y
# 125        0.5      0.75       0.503721      2         K          o         K
# 126        0.5      0.75       0.858702      2         y          Y         y
# 127        0.5      0.75       0.875085      2         K          o         K
#
#     stim_low
# 0          X
# 1          X
# 2          h
# 3          h
# 4          h
# 5          X
# 6          X
# 7          X
# 8          X
# 9          X
# 10         X
# 11         h
# 12         h
# 13         X
# 14         h
# 15         h
# 16         h
# 17         h
# 18         X
# 19         h
# 20         X
# 21         h
# 22         h
# 23         h
# 24         X
# 25         X
# 26         X
# 27         X
# 28         h
# 29         X
# 30         X
# 31         h
# 32         X
# 33         X
# 34         h
# 35         h
# 36         X
# 37         h
# 38         h
# 39         X
# 40         h
# 41         X
# 42         h
# 43         X
# 44         h
# 45         h
# 46         X
# 47         X
# 48         X
# 49         X
# 50         X
# 51         X
# 52         X
# 53         h
# 54         h
# 55         X
# 56         X
# 57         h
# 58         X
# 59         h
# 60         h
# 61         X
# 62         h
# 63         X
# 64         h
# 65         h
# 66         X
# 67         X
# 68         h
# 69         h
# 70         X
# 71         h
# 72         h
# 73         X
# 74         X
# 75         X
# 76         h
# 77         h
# 78         X
# 79         h
# 80         h
# 81         X
# 82         X
# 83         h
# 84         X
# 85         X
# 86         h
# 87         X
# 88         h
# 89         h
# 90         X
# 91         X
# 92         h
# 93         h
# 94         X
# 95         X
# 96         h
# 97         X
# 98         h
# 99         X
# 100        X
# 101        X
# 102        h
# 103        h
# 104        X
# 105        h
# 106        X
# 107        h
# 108        h
# 109        h
# 110        h
# 111        X
# 112        h
# 113        h
# 114        X
# 115        h
# 116        X
# 117        X
# 118        h
# 119        X
# 120        h
# 121        h
# 122        h
# 123        X
# 124        h
# 125        h
# 126        X
# 127        h
# 0          Y
# 1          Y
# 2          o
# 3          o
# 4          o
# 5          o
# 6          o
# 7          Y
# 8          Y
# 9          Y
# 10         o
# 11         Y
# 12         Y
# 13         o
# 14         Y
# 15         Y
# 16         o
# 17         o
# 18         Y
# 19         o
# 20         Y
# 21         o
# 22         Y
# 23         o
# 24         Y
# 25         o
# 26         Y
# 27         Y
# 28         Y
# 29         o
# 30         Y
# 31         o
# 32         Y
# 33         Y
# 34         Y
# 35         o
# 36         Y
# 37         Y
# 38         o
# 39         Y
# 40         Y
# 41         o
# 42         o
# 43         o
# 44         o
# 45         Y
# 46         o
# 47         o
# 48         o
# 49         o
# 50         Y
# 51         o
# 52         o
# 53         Y
# 54         Y
# 55         o
# 56         Y
# 57         Y
# 58         o
# 59         o
# 60         Y
# 61         o
# 62         o
# 63         o
# 64         Y
# 65         Y
# 66         o
# 67         o
# 68         Y
# 69         o
# 70         Y
# 71         o
# 72         Y
# 73         o
# 74         o
# 75         o
# 76         Y
# 77         Y
# 78         Y
# 79         o
# 80         o
# 81         Y
# 82         Y
# 83         Y
# 84         Y
# 85         o
# 86         Y
# 87         o
# 88         o
# 89         o
# 90         Y
# 91         Y
# 92         o
# 93         o
# 94         Y
# 95         o
# 96         o
# 97         Y
# 98         o
# 99         o
# 100        o
# 101        o
# 102        o
# 103        o
# 104        o
# 105        Y
# 106        o
# 107        Y
# 108        Y
# 109        Y
# 110        Y
# 111        Y
# 112        Y
# 113        Y
# 114        o
# 115        Y
# 116        Y
# 117        o
# 118        o
# 119        Y
# 120        Y
# 121        o
# 122        Y
# 123        Y
# 124        Y
# 125        o
# 126        Y
# 127        o

# %% [markdown]
# # Create session 2
#
# galgolitsa alphabeth
#  (1 = agathodaimon, 2 = galgolitsa)

# %%
def get_stimuli(subject_id, design):    
    if subject_id == 'PRACTICE':
        # The practice session always gets different stimuli
        stim_sets = [['j', 'm'], ['s', 'y'], ['u', 'n'], ['j', 'm'], ['s', 'y'], ['u', 'n']]
    else:
        stim_sets = [['É','Ï'],
                    ['K', 'h'],
                    ['y', 'z'],
                    ['L', 'v']]
            
    if subject_id == 'DEBUG' or subject_id == 'PRACTICE':
        # just use counterbalancing order 1 for practice & debug
        subject_id = 1
       
    all_stim = counterbalance_stimuli(subject_id, all_sets=stim_sets)
    design['stim_left'] = None
    design['stim_right'] = None
    design['stim_high'] = None
    design['stim_low'] = None


    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        design.loc[idx_this_stim, 'stim_high'] = all_stim[i][0]
        design.loc[idx_this_stim, 'stim_low'] = all_stim[i][1]

    for i in range(len(all_stim)):
        idx_this_stim = design.stimulus_set == i
        idx_this_stim_nonrev = (idx_this_stim) & (design.correct_stim_lr == 0)
        idx_this_stim_rev = (idx_this_stim) & (design.correct_stim_lr == 1)

        design.loc[idx_this_stim_nonrev, 'stim_left'] = design.loc[idx_this_stim_nonrev, 'stim_high']
        design.loc[idx_this_stim_nonrev, 'stim_right'] = design.loc[idx_this_stim_nonrev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_left'] = design.loc[idx_this_stim_rev, 'stim_low']
        design.loc[idx_this_stim_rev, 'stim_right'] = design.loc[idx_this_stim_rev, 'stim_high']
   
    return design

# %%
tr = 2
n_subjects = 100
n_runs = 1      # set to one less than blocks you want 

save_dir = '../designs_reversal-learning'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.arange(1,n_subjects+1):
    designs_this_session = []
    print(subject_id)
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in range(1,n_runs*2+1):
        settings = get_settings(tr=tr)
#        _, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)

        stim_set = [0, 1]
        include_cue = False
        
        # reversals
        reversals = (26, 38)
        
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(settings['n_trials'],
                                       settings['jitter'], 
                                       ps=settings['ps'],
                                       
                                       reversal_n_trials=reversals,
                                       
                                       stim_sets=stim_set,
                                       mr_design=False, 
                                       include_cue=include_cue)
        design['block'] = run
        design['stimulus_set'] = design['stimulus_set'] + 2*(run-1)
        designs_this_session.append(design)
        
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    
    
    design.rename(columns={'phase_1': 'fix_cross_1',
                           'phase_2': 'cue',
                           'phase_3': 'fix_cross_2',
                           'phase_4': 'stimulus',
                           'phase_5': 'highlight',
                           'phase_6': 'feedback',
                           'phase_7': 'iti_posttrial'}, 
                  inplace=True)
    
    fn = 'sub-' + str(subject_id).zfill(3) + '_ses-2_task-reversal-learning_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 1, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 1, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-001_ses-2_task-reversal-learning_design
# 2
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 2, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 2, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-002_ses-2_task-reversal-learning_design
# 3
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 3, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 3, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-003_ses-2_task-reversal-learning_design
# 4
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 4, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 4, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-004_ses-2_task-reversal-learning_design
# 5
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 5, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 5, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-005_ses-2_task-reversal-learning_design
# 6
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 6, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 6, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-006_ses-2_task-reversal-learning_design
# 7
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 7, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 7, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-007_ses-2_task-reversal-learning_design
# 8
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 8, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 8, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-008_ses-2_task-reversal-learning_design
# 9
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 9, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 9, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-009_ses-2_task-reversal-learning_design
# 10
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 10, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 10, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-010_ses-2_task-reversal-learning_design
# 11
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 11, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 11, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-011_ses-2_task-reversal-learning_design
# 12
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 12, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 12, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-012_ses-2_task-reversal-learning_design
# 13
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 13, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 13, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-013_ses-2_task-reversal-learning_design
# 14
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 14, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 14, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-014_ses-2_task-reversal-learning_design
# 15
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 15, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 15, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-015_ses-2_task-reversal-learning_design
# 16
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 16, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 16, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-016_ses-2_task-reversal-learning_design
# 17
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 17, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 17, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-017_ses-2_task-reversal-learning_design
# 18
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 18, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 18, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-018_ses-2_task-reversal-learning_design
# 19
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 19, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 19, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-019_ses-2_task-reversal-learning_design
# 20
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 20, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 20, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-020_ses-2_task-reversal-learning_design
# 21
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 21, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 21, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-021_ses-2_task-reversal-learning_design
# 22
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 22, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 22, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-022_ses-2_task-reversal-learning_design
# 23
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 23, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 23, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-023_ses-2_task-reversal-learning_design
# 24
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 24, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 24, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-024_ses-2_task-reversal-learning_design
# 25
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 25, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 25, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-025_ses-2_task-reversal-learning_design
# 26
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 26, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 26, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-026_ses-2_task-reversal-learning_design
# 27
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 27, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 27, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-027_ses-2_task-reversal-learning_design
# 28
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 28, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 28, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-028_ses-2_task-reversal-learning_design
# 29
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 29, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 29, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-029_ses-2_task-reversal-learning_design
# 30
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 30, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 30, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-030_ses-2_task-reversal-learning_design
# 31
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 31, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 31, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-031_ses-2_task-reversal-learning_design
# 32
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 32, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 32, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-032_ses-2_task-reversal-learning_design
# 33
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 33, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 33, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-033_ses-2_task-reversal-learning_design
# 34
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 34, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 34, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-034_ses-2_task-reversal-learning_design
# 35
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 35, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 35, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-035_ses-2_task-reversal-learning_design
# 36
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 36, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 36, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-036_ses-2_task-reversal-learning_design
# 37
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 37, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 37, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-037_ses-2_task-reversal-learning_design
# 38
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 38, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 38, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-038_ses-2_task-reversal-learning_design
# 39
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 39, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 39, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-039_ses-2_task-reversal-learning_design
# 40
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 40, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 40, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-040_ses-2_task-reversal-learning_design
# 41
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 41, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 41, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-041_ses-2_task-reversal-learning_design
# 42
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 42, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 42, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-042_ses-2_task-reversal-learning_design
# 43
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 43, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 43, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-043_ses-2_task-reversal-learning_design
# 44
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 44, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 44, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-044_ses-2_task-reversal-learning_design
# 45
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 45, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 45, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-045_ses-2_task-reversal-learning_design
# 46
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 46, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 46, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-046_ses-2_task-reversal-learning_design
# 47
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 47, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 47, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-047_ses-2_task-reversal-learning_design
# 48
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 48, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 48, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-048_ses-2_task-reversal-learning_design
# 49
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 49, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 49, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-049_ses-2_task-reversal-learning_design
# 50
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 50, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 50, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-050_ses-2_task-reversal-learning_design
# 51
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 51, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 51, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-051_ses-2_task-reversal-learning_design
# 52
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 52, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 52, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-052_ses-2_task-reversal-learning_design
# 53
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 53, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 53, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-053_ses-2_task-reversal-learning_design
# 54
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 54, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 54, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-054_ses-2_task-reversal-learning_design
# 55
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 55, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 55, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-055_ses-2_task-reversal-learning_design
# 56
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 56, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 56, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-056_ses-2_task-reversal-learning_design
# 57
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 57, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 57, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-057_ses-2_task-reversal-learning_design
# 58
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 58, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 58, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-058_ses-2_task-reversal-learning_design
# 59
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 59, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 59, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-059_ses-2_task-reversal-learning_design
# 60
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 60, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# ...
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 81, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 81, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-081_ses-2_task-reversal-learning_design
# 82
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 82, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 82, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-082_ses-2_task-reversal-learning_design
# 83
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 83, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 83, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-083_ses-2_task-reversal-learning_design
# 84
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 84, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 84, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-084_ses-2_task-reversal-learning_design
# 85
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 85, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 85, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-085_ses-2_task-reversal-learning_design
# 86
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 86, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 86, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-086_ses-2_task-reversal-learning_design
# 87
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 87, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 87, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-087_ses-2_task-reversal-learning_design
# 88
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 88, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 88, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-088_ses-2_task-reversal-learning_design
# 89
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 89, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 89, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-089_ses-2_task-reversal-learning_design
# 90
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 90, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 90, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-090_ses-2_task-reversal-learning_design
# 91
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 91, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 91, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['y', 'z'], ['L', 'v'], ['É', 'Ï'], ['K', 'h']]
# sub-091_ses-2_task-reversal-learning_design
# 92
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 92, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 92, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['z', 'y'], ['v', 'L'], ['Ï', 'É'], ['h', 'K']]
# sub-092_ses-2_task-reversal-learning_design
# 93
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 93, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 93, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-093_ses-2_task-reversal-learning_design
# 94
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 94, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 94, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-094_ses-2_task-reversal-learning_design
# 95
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 95, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 95, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['L', 'v'], ['y', 'z'], ['K', 'h'], ['É', 'Ï']]
# sub-095_ses-2_task-reversal-learning_design
# 96
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 96, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 96, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['v', 'L'], ['z', 'y'], ['h', 'K'], ['Ï', 'É']]
# sub-096_ses-2_task-reversal-learning_design
# 97
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 97, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 97, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['É', 'Ï'], ['K', 'h'], ['y', 'z'], ['L', 'v']]
# sub-097_ses-2_task-reversal-learning_design
# 98
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 98, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 98, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['Ï', 'É'], ['h', 'K'], ['z', 'y'], ['v', 'L']]
# sub-098_ses-2_task-reversal-learning_design
# 99
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 99, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 99, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['K', 'h'], ['É', 'Ï'], ['L', 'v'], ['y', 'z']]
# sub-099_ses-2_task-reversal-learning_design
# 100
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 100, run: 1, cue: False
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: 100, run: 2, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'K'], ['Ï', 'É'], ['v', 'L'], ['z', 'y']]
# sub-100_ses-2_task-reversal-learning_design

# %%
design.head()
# Out:
#    stimulus_set  correct_stim_lr cue_txt  reversal p_win_left p_win_right  \
# 0             0                0               0.0        0.8         0.2
# 1             1                1               0.0        0.3         0.7
# 2             1                1               0.0        0.3         0.7
# 3             1                0               0.0        0.7         0.3
# 4             0                0               0.0        0.8         0.2
#
#   p_win_correct p_win_incorrect  fix_cross_1     cue  fix_cross_2  stimulus  \
# 0           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 1           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 2           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 3           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 4           0.8             0.2      -0.0001 -0.0001      -0.0001         2
#
#    highlight  feedback  iti_posttrial  block stim_left stim_right stim_high  \
# 0        0.5      0.75       0.617054      1         h          K         h
# 1        0.5      0.75       0.578859      1         É          Ï         Ï
# 2        0.5      0.75       0.620712      1         É          Ï         Ï
# 3        0.5      0.75       0.835271      1         Ï          É         Ï
# 4        0.5      0.75       0.756896      1         h          K         h
#
#   stim_low
# 0        K
# 1        É
# 2        É
# 3        É
# 4        K

# %%
design.tail()
# Out:
#      stimulus_set  correct_stim_lr cue_txt  reversal p_win_left p_win_right  \
# 123             3                0               1.0        0.3         0.7
# 124             3                0               1.0        0.3         0.7
# 125             3                1               1.0        0.7         0.3
# 126             3                0               1.0        0.3         0.7
# 127             3                1               1.0        0.7         0.3
#
#     p_win_correct p_win_incorrect  fix_cross_1     cue  fix_cross_2  stimulus  \
# 123           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 124           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 125           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 126           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 127           0.7             0.3      -0.0001 -0.0001      -0.0001         2
#
#      highlight  feedback  iti_posttrial  block stim_left stim_right stim_high  \
# 123        0.5      0.75       0.802601      2         z          y         z
# 124        0.5      0.75       0.925072      2         z          y         z
# 125        0.5      0.75       0.662206      2         y          z         z
# 126        0.5      0.75       0.842994      2         z          y         z
# 127        0.5      0.75       0.846191      2         y          z         z
#
#     stim_low
# 123        y
# 124        y
# 125        y
# 126        y
# 127        y

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ________________________________ below not needed _______________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ## For debug, we create a nice a short session

# %%
tr = 2
n_subjects = 1
n_runs = 1

save_dir = '../designs'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.hstack(['DEBUG']):
    designs_this_session = []
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in range(1,n_runs*2+1):
        settings = get_settings(tr=tr)
        include_cue, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(6, settings['jitter'], ps=settings['ps'],
                                       stim_sets=stim_set,
                                       mr_design=False, include_cue=include_cue)
        design['block'] = run
        designs_this_session.append(design)
    
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    fn = 'sub-' + str(subject_id).zfill(2) + '_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: DEBUG, run: 1, cue: False
# WARNING: not totally balanced (6 not a multitude of 4)
# 0 0
# 1 1
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: DEBUG, run: 2, cue: False
# WARNING: not totally balanced (6 not a multitude of 4)
# 0 0
# 1 1
# Stimuli/set order for this pp: [['h', 'i'], ['X', 'e'], ['u', 'n'], ['o', 'K'], ['Y', 'y'], ['P', 'A']]
# sub-DEBUG_design

# %%
design.head()
# Out:
#    stimulus_set  correct_stim_lr cue_txt  reversal p_win_left p_win_right  \
# 0             1                1               0.0        0.3         0.7
# 1             1                0               0.0        0.7         0.3
# 2             0                0               0.0        0.8         0.2
# 3             1                0               0.0        0.7         0.3
# 4             0                0               0.0        0.8         0.2
#
#   p_win_correct p_win_incorrect  fix_cross_1     cue  fix_cross_2  stimulus  \
# 0           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 1           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 2           0.8             0.2      -0.0001 -0.0001      -0.0001         2
# 3           0.7             0.3      -0.0001 -0.0001      -0.0001         2
# 4           0.8             0.2      -0.0001 -0.0001      -0.0001         2
#
#    highlight  feedback  iti_posttrial  block stim_left stim_right stim_high  \
# 0        0.5      0.75       0.518997      1         d          L         L
# 1        0.5      0.75       0.977827      1         L          d         L
# 2        0.5      0.75       0.534103      1         y          z         y
# 3        0.5      0.75       0.786755      1         L          d         L
# 4        0.5      0.75       0.903140      1         y          z         y
#
#   stim_low
# 0        d
# 1        d
# 2        z
# 3        d
# 4        z

# %%
#print all lines 

#show all columns
with pd.option_context('display.max_rows', None):
    display(design)
# Out:
#     stimulus_set  correct_stim_lr cue p_win_left p_win_right p_win_correct  \
# 0              1                0            0.7         0.3           0.7
# 1              1                1            0.3         0.7           0.7
# 2              0                0            0.8         0.2           0.8
# 3              1                1            0.3         0.7           0.7
# 4              0                0            0.8         0.2           0.8
# 5              1                0            0.7         0.3           0.7
# 6              0                1            0.2         0.8           0.8
# 7              1                1            0.3         0.7           0.7
# 8              0                1            0.2         0.8           0.8
# 9              0                1            0.2         0.8           0.8
# 10             0                0            0.8         0.2           0.8
# 11             1                0            0.7         0.3           0.7
#
#    p_win_incorrect  reversal  phase_1  phase_2  phase_3  phase_4  phase_5  \
# 0              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 1              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 2              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 3              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 4              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 5              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 6              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 7              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 8              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 9              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 10             0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 11             0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
#
#     phase_6   phase_7  block stim_left stim_right stim_high stim_low
# 0      0.75  0.726047      1         J          K         J        K
# 1      0.75  0.661562      1         K          J         J        K
# 2      0.75  0.898201      1         A          B         A        B
# 3      0.75  0.954166      1         K          J         J        K
# 4      0.75  0.722564      1         A          B         A        B
# 5      0.75  0.803111      1         J          K         J        K
# 6      0.75  0.952858      1         B          A         A        B
# 7      0.75  0.671067      1         K          J         J        K
# 8      0.75  0.869663      1         B          A         A        B
# 9      0.75  0.512313      1         B          A         A        B
# 10     0.75  0.846313      1         A          B         A        B
# 11     0.75  0.895300      1         J          K         J        K

# %% [markdown]
# ### Idem for the practice session

# %%
tr = 2
n_runs = 1


save_dir = '../designs'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
for subject_id in np.hstack(['PRACTICE']):
    designs_this_session = []
    is_practice = subject_id == 'PRACTICE'
    is_debug = subject_id == 'DEBUG'
    
    for run in [1]:
        settings = get_settings(tr=tr)
        include_cue, stim_set = get_task_type(run, subject_id, is_practice=is_practice, is_debug=is_debug)
        print('Subject: %s, run: %d, cue: %s' %(subject_id, run, include_cue))
        design = generate_block_design(12, settings['jitter'], ps=settings['ps'],
                                       stim_sets=stim_set,
                                       mr_design=False, include_cue=include_cue, practice=True)
        design['block'] = run
        designs_this_session.append(design)
    
    design = pd.concat(designs_this_session)
    design = get_stimuli(subject_id=subject_id, design=design)
    fn = 'sub-' + str(subject_id).zfill(2) + '_design'
    print(fn)
    design.to_csv(save_dir + '/' + fn + '.csv', sep='\t', index_label='trial_ID')
# Out:
# Settings:
#
#         Sessions: 1
#         Trials per run: 128
#         Assuming a TR of 2 seconds
#         Jitter options: [0.5, 0.75, 1, 1.25, 1.5] seconds
#         Total duration: 2*8*128 = 1024 seconds = 17.066666666666666 min
#         Total number of volumes necessary: 1+128*4 = 513 + warm-up pulses
# Subject: PRACTICE, run: 1, cue: False
# 0 0
# 1 1
# Stimuli/set order for this pp: [['j', 'm'], ['s', 'y'], ['u', 'n'], ['j', 'm'], ['s', 'y'], ['u', 'n']]
# sub-PRACTICE_design

# %%
design
# Out:
#     stimulus_set  correct_stim_lr cue p_win_left p_win_right p_win_correct  \
# 0              1                0            0.7         0.3           0.7
# 1              1                1            0.3         0.7           0.7
# 2              0                0            0.8         0.2           0.8
# 3              1                1            0.3         0.7           0.7
# 4              0                0            0.8         0.2           0.8
# 5              1                0            0.7         0.3           0.7
# 6              0                1            0.2         0.8           0.8
# 7              1                1            0.3         0.7           0.7
# 8              0                1            0.2         0.8           0.8
# 9              0                1            0.2         0.8           0.8
# 10             0                0            0.8         0.2           0.8
# 11             1                0            0.7         0.3           0.7
#
#    p_win_incorrect  reversal  phase_1  phase_2  phase_3  phase_4  phase_5  \
# 0              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 1              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 2              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 3              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 4              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 5              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 6              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 7              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 8              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 9              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 10             0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 11             0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
#
#     phase_6   phase_7  block stim_left stim_right stim_high stim_low
# 0      0.75  0.726047      1         J          K         J        K
# 1      0.75  0.661562      1         K          J         J        K
# 2      0.75  0.898201      1         A          B         A        B
# 3      0.75  0.954166      1         K          J         J        K
# 4      0.75  0.722564      1         A          B         A        B
# 5      0.75  0.803111      1         J          K         J        K
# 6      0.75  0.952858      1         B          A         A        B
# 7      0.75  0.671067      1         K          J         J        K
# 8      0.75  0.869663      1         B          A         A        B
# 9      0.75  0.512313      1         B          A         A        B
# 10     0.75  0.846313      1         A          B         A        B
# 11     0.75  0.895300      1         J          K         J        K

# %%
idx = design.block == 2

# %%
idx
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: block, dtype: bool

# %%
1 < np.cumsum(idx) < 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-08453ded52bb> in <module>
# ----> 1 1 < np.cumsum(idx) < 2
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
idx = design.block == 1
#idx & np.cumsum(idx) < 4

# %%
idx = design.block==1
design.loc[idx].groupby(['stimulus_set'])[['stim_left', 'stim_right']].last().reset_index()[['stim_left', 'stim_right']].values.tolist()
# Out:
# [['B', 'A'], ['K', 'J']]

# %%
design[['stim_left', 'stim_right']].values
# Out:
# array([['j', 'm'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['y', 's'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['y', 's'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['m', 'j'],
#        ['j', 'm'],
#        ['j', 'm'],
#        ['y', 's'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['j', 'm'],
#        ['s', 'y'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['y', 's'],
#        ['y', 's'],
#        ['m', 'j'],
#        ['m', 'j'],
#        ['s', 'y'],
#        ['j', 'm'],
#        ['m', 'j'],
#        ['j', 'm'],
#        ['s', 'y'],
#        ['y', 's'],
#        ['s', 'y'],
#        ['m', 'j'],
#        ['j', 'm'],
#        ['j', 'm'],
#        ['y', 's'],
#        ['y', 's'],
#        ['s', 'y'],
#        ['m', 'j']], dtype=object)

# %%
design['stim_right'].uni
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-738c28da7cc3> in <module>
# ----> 1 design['stim_right'].uni
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'uni'

# %%
#show all columns
with pd.option_context('display.max_rows', None):
    display(design)
# Out:
#     stimulus_set  correct_stim_lr cue p_win_left p_win_right p_win_correct  \
# 0              1                0            0.7         0.3           0.7
# 1              1                1            0.3         0.7           0.7
# 2              0                0            0.8         0.2           0.8
# 3              1                1            0.3         0.7           0.7
# 4              0                0            0.8         0.2           0.8
# 5              1                0            0.7         0.3           0.7
# 6              0                1            0.2         0.8           0.8
# 7              1                1            0.3         0.7           0.7
# 8              0                1            0.2         0.8           0.8
# 9              0                1            0.2         0.8           0.8
# 10             0                0            0.8         0.2           0.8
# 11             1                0            0.7         0.3           0.7
#
#    p_win_incorrect  reversal  phase_1  phase_2  phase_3  phase_4  phase_5  \
# 0              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 1              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 2              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 3              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 4              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 5              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 6              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 7              0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 8              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 9              0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 10             0.2       0.0  -0.0001  -0.0001  -0.0001        2      0.5
# 11             0.3       0.0  -0.0001  -0.0001  -0.0001        2      0.5
#
#     phase_6   phase_7  block stim_left stim_right stim_high stim_low
# 0      0.75  0.726047      1         J          K         J        K
# 1      0.75  0.661562      1         K          J         J        K
# 2      0.75  0.898201      1         A          B         A        B
# 3      0.75  0.954166      1         K          J         J        K
# 4      0.75  0.722564      1         A          B         A        B
# 5      0.75  0.803111      1         J          K         J        K
# 6      0.75  0.952858      1         B          A         A        B
# 7      0.75  0.671067      1         K          J         J        K
# 8      0.75  0.869663      1         B          A         A        B
# 9      0.75  0.512313      1         B          A         A        B
# 10     0.75  0.846313      1         A          B         A        B
# 11     0.75  0.895300      1         J          K         J        K
